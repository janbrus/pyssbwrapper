# %% [markdown]
# <a href="https://colab.research.google.com/github/kirajcg/pyscbwrapper/blob/master/pyscbwrapper_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# We want to construct a graph over the population density in each county ('län') in Sweden over time. To help with this we have Statistics Sweden's data and Python, and our goal is to not have to leave the Python environment to not even fetch the data. Luckily there is a custom made package for this purpose, called pyscbwrapper.

# %% [markdown]
# # Installation

# %% [markdown]
# pyscbwrapper is a kind of interface to the Statistical Database, written in Python 3. To run this interface we first need to install and import it. (If you do not have access to Python you can run this via Colab by clicking the button above.)

# %%
# !pip install -q pyscbwrapper
from pyssbwrapper import SSB

# %% [markdown]
# # Initialisation

# %% [markdown]
# SCB is now a class we have imported, containing functions for navigating in the Statistical Database and fetch metadata as well as data from it. To use the SCB class we first need to initialise an object from it. Then we need one mandatory argument: language for the data and metadata. English and Swedish are supported. We choose English:

# %%
ssb = SSB('en')

# %% [markdown]
# # Navigation and metadata

# %% [markdown]
# Now we can look at the top node in the tree that is the Statistical Database's metadata:

# %%
ssb.info()
# Out:
# [{'id': 'al', 'type': 'l', 'text': 'Labour market and earnings'},
#  {'id': 'bf', 'type': 'l', 'text': 'Banking and financial markets'},
#  {'id': 'vf', 'type': 'l', 'text': 'Establishments, enterprises and accounts'},
#  {'id': 'be', 'type': 'l', 'text': 'Population'},
#  {'id': 'bb', 'type': 'l', 'text': 'Construction, housing and property'},
#  {'id': 'ei', 'type': 'l', 'text': 'Energy and manufacturing'},
#  {'id': 'he', 'type': 'l', 'text': 'Health'},
#  {'id': 'if', 'type': 'l', 'text': 'Income and consumption'},
#  {'id': 'in', 'type': 'l', 'text': 'Immigration and immigrants'},
#  {'id': 'js',
#   'type': 'l',
#   'text': 'Agriculture, forestry, hunting and fishing'},
#  {'id': 'kf', 'type': 'l', 'text': 'Culture and recreation'},
#  {'id': 'nk', 'type': 'l', 'text': 'National accounts and business cycles'},
#  {'id': 'nm', 'type': 'l', 'text': 'Nature and the environment'},
#  {'id': 'os', 'type': 'l', 'text': 'Public sector'},
#  {'id': 'pp', 'type': 'l', 'text': 'Prices and price indices'},
#  {'id': 'sk', 'type': 'l', 'text': 'Social conditions, welfare and crime'},
#  {'id': 'sv', 'type': 'l', 'text': 'Svalbard'},
#  {'id': 'ti', 'type': 'l', 'text': 'Technology and innovation'},
#  {'id': 'tr', 'type': 'l', 'text': 'Transport and tourism'},
#  {'id': 'ud', 'type': 'l', 'text': 'Education'},
#  {'id': 'ut', 'type': 'l', 'text': 'External economy'},
#  {'id': 'va', 'type': 'l', 'text': 'Elections'},
#  {'id': 'vt',
#   'type': 'l',
#   'text': 'Wholesale and retail trade and service activities'}]

# %% [markdown]
# We can now go down in the tree by using the id tag in the metadata we fetched. Let's say we are interested in the population statistics.

# %%
ssb.go_down('be')

# %% [markdown]
# To fetch the metadata about the population statistics, we once again run the function info():

# %%
ssb.info()
# Out:
# [{'id': 'be01', 'type': 'l', 'text': 'Children, families and households'},
#  {'id': 'be02', 'type': 'l', 'text': 'Population projections'},
#  {'id': 'be03', 'type': 'l', 'text': 'Migration'},
#  {'id': 'be05', 'type': 'l', 'text': 'Population count'},
#  {'id': 'be06', 'type': 'l', 'text': 'Births and deaths'},
#  {'id': 'be07', 'type': 'l', 'text': 'Immigrants'},
#  {'id': 'be08', 'type': 'l', 'text': 'Gender equality'},
#  {'id': 'be09', 'type': 'l', 'text': 'Names'},
#  {'id': 'be11', 'type': 'l', 'text': 'Regions'}]

# %% [markdown]
# We can keep going down in the tree:

# %%
ssb.go_down('be09')
ssb.info()
# Out:
# [{'id': 'navn', 'type': 'l', 'text': 'Names'}]

# %% [markdown]
# Whoops! We did not want the name statistics, but the population statistics. We go up one step and back down to the correct node:

# %%
ssb.go_up()
ssb.go_down('be05')
ssb.info()
# Out:
# [{'id': 'befsvalbard', 'type': 'l', 'text': 'Population of Svalbard'},
#  {'id': 'beftett',
#   'type': 'l',
#   'text': 'Population and land area in urban settlements'},
#  {'id': 'flyktninger', 'type': 'l', 'text': 'Refugees'},
#  {'id': 'fobbolig',
#   'type': 'l',
#   'text': 'Population and Housing Census, dwellings (discontinued)'},
#  {'id': 'fobhoved',
#   'type': 'l',
#   'text': 'Population and Housing Census, main figures (discontinued)'},
#  {'id': 'fobhushold',
#   'type': 'l',
#   'text': 'Population and Housing Census, households (discontinued)'},
#  {'id': 'fobhusinnt',
#   'type': 'l',
#   'text': 'Population and Housing Census, household income (discontinued)'},
#  {'id': 'fobinnvbolig',
#   'type': 'l',
#   'text': 'Population and Housing Census, housing conditions of immigrants (discontinued)'},
#  {'id': 'fobsysut',
#   'type': 'l',
#   'text': 'Population and Housing Census, employment and education (discontinued)'},
#  {'id': 'folkemengde', 'type': 'l', 'text': 'Population'},
#  {'id': 'folkfram', 'type': 'l', 'text': 'National population projections'},
#  {'id': 'innvbef',
#   'type': 'l',
#   'text': 'Immigrants and Norwegian-born to immigrant parents'},
#  {'id': 'regfram', 'type': 'l', 'text': 'Regional population projections'},
#  {'id': 'samisk', 'type': 'l', 'text': 'Sami'}]

# %% [markdown]
# # Direct route to specific nodes

# %% [markdown]
#  If we know where in the tree we want to go, we can initialise an object using the id tags as extra variables:

# %%
ssb = SSB('en', 'be', 'be05', 'folkemengde')
ssb.info()
# Out:
# [{'id': 'SBMENU6924',
#   'type': 'h',
#   'text': 'Municipalities, counties and the whole country, population per 1 January'},
#  {'id': 'NY3026',
#   'type': 't',
#   'text': '07459: Population, by sex and one-year age groups  (M) 1986 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'Folkemengd1951',
#   'type': 't',
#   'text': '06913: Population 1 January and population changes during the calendar year (M) 1951 - 2025',
#   'updated': '2025-03-13T08:00:00'},
#  {'id': 'Rd0002AaX2',
#   'type': 't',
#   'text': '03027: Population, by marital status (M) 1986 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'Rd0002AaX5',
#   'type': 't',
#   'text': '03031: Population, by sex, age and marital status (C) 1986 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'FolkemengdAreal',
#   'type': 't',
#   'text': '11342: Population and area (M) 2007 - 2025',
#   'updated': '2025-02-26T08:00:00'},
#  {'id': 'BefolkKomStor',
#   'type': 't',
#   'text': '12871: Population, by size of municipality, sex and age 2017 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'Folkemengde01',
#   'type': 't',
#   'text': '13536: Mean and median age in municipalities, counties and the entire populace (M) 2000 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'SBMENU3946',
#   'type': 'h',
#   'text': 'Quarterly figures for municipalities, counties and the whole country'},
#  {'id': 'Rd1222Kv',
#   'type': 't',
#   'text': '01222: Population and changes during the quarter (M) 1997K4 - 2025K2',
#   'updated': '2025-08-21T08:00:00'},
#  {'id': 'Rd1223Kv',
#   'type': 't',
#   'text': '01223: Population and changes so far this year (M) 1997K4 - 2025K2',
#   'updated': '2025-08-21T08:00:00'},
#  {'id': 'FlyttFraOgTilKvLa',
#   'type': 't',
#   'text': '11327: Immigration, emigration and net immigration, by citizenship 2007K1 - 2025K2',
#   'updated': '2025-08-21T08:00:00'},
#  {'id': 'SBMENU5580', 'type': 'h', 'text': 'Long time series'},
#  {'id': 'FolkHistorie',
#   'type': 't',
#   'text': '05803: Population 1 January and population changes during the calendar year 1735 - 2025',
#   'updated': '2025-05-16T08:00:00'},
#  {'id': 'FolkemEttAarig',
#   'type': 't',
#   'text': '10211: Population, by sex and age 1846 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'EkteStatusHist7',
#   'type': 't',
#   'text': '05813: Resident population, by sex and marital status 1769 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'FolkmengdHist4',
#   'type': 't',
#   'text': '05810: Population, by sex and age 1845 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'SBMENU6923', 'type': 'h', 'text': 'Citizenship'},
#  {'id': 'FolkStatsb',
#   'type': 't',
#   'text': '11366: Population, by citizenship (M) (UD) 2016 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'FolkKjStatsb2',
#   'type': 't',
#   'text': '05196: Population, by sex, age and citizenship 1977 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'FolkSivilStat2',
#   'type': 't',
#   'text': '05328: Population, by sex, marital status and citizenship 2000 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'SBMENU6922',
#   'type': 'h',
#   'text': 'Urban districts and basic statistical units'},
#  {'id': 'FolkemBydEttar',
#   'type': 't',
#   'text': '10826: Population, by sex and age (UD) 2001 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'FolkGrunnkrKom',
#   'type': 't',
#   'text': '04317: Population, by basic statistical unit  (BU) 1999 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'FoBKhtab28II',
#   'type': 't',
#   'text': '04362: Population, by sex and age (BU) 2001 - 2025',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'SBMENU6920', 'type': 'h', 'text': 'Mean population'},
#  {'id': 'Rd1352AaX1',
#   'type': 't',
#   'text': '03037: Mean population, by ten year age groups, sex and marital status (C) 1987 - 2024',
#   'updated': '2025-02-25T08:00:00'},
#  {'id': 'BefEndrRate',
#   'type': 't',
#   'text': '07236: Mean population and population changes per 1000 population 1997K4 - 2025K2',
#   'updated': '2025-08-21T08:00:00'},
#  {'id': 'SBMENU8781', 'type': 'l', 'text': 'Children and young people'},
#  {'id': 'SBMENU7983', 'type': 'l', 'text': 'Closed time series'},
#  {'id': 'FRA_GAMMEL_00039', 'type': 'l', 'text': 'Closed long time series'}]

# %% [markdown]
# As you can see, we end up directly in the population statistics.
#
# ---
#
# The specific initialisation of the object does not stop us from navigating in the tree:

# %%
ssb.go_up()
ssb.info()
# Out:
# [{'id': 'befsvalbard', 'type': 'l', 'text': 'Population of Svalbard'},
#  {'id': 'beftett',
#   'type': 'l',
#   'text': 'Population and land area in urban settlements'},
#  {'id': 'flyktninger', 'type': 'l', 'text': 'Refugees'},
#  {'id': 'fobbolig',
#   'type': 'l',
#   'text': 'Population and Housing Census, dwellings (discontinued)'},
#  {'id': 'fobhoved',
#   'type': 'l',
#   'text': 'Population and Housing Census, main figures (discontinued)'},
#  {'id': 'fobhushold',
#   'type': 'l',
#   'text': 'Population and Housing Census, households (discontinued)'},
#  {'id': 'fobhusinnt',
#   'type': 'l',
#   'text': 'Population and Housing Census, household income (discontinued)'},
#  {'id': 'fobinnvbolig',
#   'type': 'l',
#   'text': 'Population and Housing Census, housing conditions of immigrants (discontinued)'},
#  {'id': 'fobsysut',
#   'type': 'l',
#   'text': 'Population and Housing Census, employment and education (discontinued)'},
#  {'id': 'folkemengde', 'type': 'l', 'text': 'Population'},
#  {'id': 'folkfram', 'type': 'l', 'text': 'National population projections'},
#  {'id': 'innvbef',
#   'type': 'l',
#   'text': 'Immigrants and Norwegian-born to immigrant parents'},
#  {'id': 'regfram', 'type': 'l', 'text': 'Regional population projections'},
#  {'id': 'samisk', 'type': 'l', 'text': 'Sami'}]

# %% [markdown]
# Anyway, we go directly back to population density:

# %%
ssb.go_down('beftett')
ssb.info()
# Out:
# [{'id': 'FolkTettSpredt',
#   'type': 't',
#   'text': '05212: Population in densely and sparsely populated areas, by sex (M) 1990 - 2024',
#   'updated': '2024-10-01T08:00:00'},
#  {'id': 'FolkTettsted',
#   'type': 't',
#   'text': '05277: Population, by age and sex (US) 1999 - 2024',
#   'updated': '2024-10-01T08:00:00'},
#  {'id': 'ArealBefTett',
#   'type': 't',
#   'text': '04859: Area and population of urban settlements (US) 2000 - 2024',
#   'updated': '2024-10-01T08:00:00'},
#  {'id': 'ArealBefKomm',
#   'type': 't',
#   'text': '04861: Area and population of urban settlements (M) 2000 - 2024',
#   'updated': '2024-10-01T08:00:00'},
#  {'id': 'ArealBefFylk',
#   'type': 't',
#   'text': '04860: Area and population of urban settlements (C) 2000 - 2024',
#   'updated': '2024-10-01T08:00:00'},
#  {'id': 'ArealBefLand',
#   'type': 't',
#   'text': '04862: Area and population of urban settlements 2000 - 2024',
#   'updated': '2024-10-01T08:00:00'},
#  {'id': 'Beftett01',
#   'type': 't',
#   'text': '14216: Area and population of urban settlements (M) (US) 2000 - 2024',
#   'updated': '2024-10-01T08:00:00'}]

# %% [markdown]
# Now there is only one nod to go to, so we do that:

# %%
ssb.go_down('FolkTettSpredt')
ssb.info()
# Out:
# {'title': '05212: Population, by region, densely/sparsely populated areas, sex, contents and year',
#  'variables': [{'code': 'Region',
#    'text': 'region',
#    'values': ['0',
#     '31',
#     '3101',
#     '3103',
#     '3105',
#     '3107',
#     '3110',
#     '3112',
#     '3114',
#     '3116',
#     '3118',
#     '3120',
#     '3122',
#     '3124',
#     '32',
#     '3201',
#     '3203',
#     '3205',
#     '3207',
#     '3209',
#     '3212',
#     '3214',
#     '3216',
#     '3218',
#     '3220',
#     '3222',
#     '3224',
#     '3226',
#     '3228',
#     '3230',
#     '3232',
#     '3234',
#     '3236',
#     '3238',
#     '3240',
#     '3242',
#     '30',
#     '01',
#     '3001',
#     '3002',
#     '3003',
#     '3004',
#     '3005',
#     '3006',
#     '3007',
#     '3011',
#     '3012',
#     '3013',
#     '3014',
#     '3015',
#     '3016',
#     '3017',
#     '3018',
#     '3019',
#     '3020',
#     '3021',
#     '3022',
#     '3023',
#     '3024',
#     '3025',
#     '3026',
#     '3027',
#     '3028',
#     '3029',
#     '3030',
#     '3031',
#     '3032',
#     '3033',
#     '3034',
#     '3035',
#     '3036',
#     '3037',
#     '3038',
#     '3039',
#     '3040',
#     '3041',
#     '3042',
#     '3043',
#     '3044',
#     '3045',
#     '3046',
#     '3047',
#     '3048',
#     '3049',
#     '3050',
#     '3051',
#     '3052',
#     '3053',
#     '3054',
#     '0101',
#     '0102',
#     '0103',
#     '0104',
#     '0105',
#     '0106',
#     '0111',
#     '0113',
#     '0114',
#     '0115',
#     '0116',
#     '0117',
#     '0118',
#     '0119',
#     '0121',
#     '0122',
#     '0123',
#     '0124',
#     '0125',
#     '0127',
#     '0128',
#     '0130',
#     '0131',
#     '0133',
#     '0134',
#     '0135',
#     '0136',
#     '0137',
#     '0138',
#     '0199',
#     '02',
#     '0211',
#     '0213',
#     '0214',
#     '0215',
#     '0216',
#     '0217',
#     '0219',
#     '0220',
#     '0221',
#     '0226',
#     '0227',
#     '0228',
#     '0229',
#     '0230',
#     '0231',
#     '0233',
#     '0234',
#     '0235',
#     '0236',
#     '0237',
#     '0238',
#     '0239',
#     '0299',
#     '03',
#     '0301',
#     '33',
#     '0399',
#     '3301',
#     '3303',
#     '3305',
#     '3310',
#     '3312',
#     '3314',
#     '3316',
#     '3318',
#     '3320',
#     '3322',
#     '3324',
#     '3326',
#     '3328',
#     '3330',
#     '3332',
#     '3334',
#     '3336',
#     '3338',
#     '34',
#     '04',
#     '3401',
#     '3403',
#     '3405',
#     '3407',
#     '3411',
#     '3412',
#     '3413',
#     '3414',
#     '3415',
#     '3416',
#     '3417',
#     '3418',
#     '3419',
#     '3420',
#     '3421',
#     '3422',
#     '3423',
#     '3424',
#     '3425',
#     '3426',
#     '3427',
#     '3428',
#     '3429',
#     '3430',
#     '3431',
#     '3432',
#     '3433',
#     '3434',
#     '3435',
#     '3436',
#     '3437',
#     '3438',
#     '3439',
#     '3440',
#     '3441',
#     '3442',
#     '3443',
#     '3446',
#     '3447',
#     '3448',
#     '3449',
#     '3450',
#     '3451',
#     '3452',
#     '3453',
#     '3454',
#     '0401',
#     '0402',
#     '0403',
#     '0412',
#     '0414',
#     '0415',
#     '0417',
#     '0418',
#     '0419',
#     '0420',
#     '0423',
#     '0425',
#     '0426',
#     '0427',
#     '0428',
#     '0429',
#     '0430',
#     '0432',
#     '0434',
#     '0435',
#     '0436',
#     '0437',
#     '0438',
#     '0439',
#     '0441',
#     '0499',
#     '05',
#     '0501',
#     '0502',
#     '0511',
#     '0512',
#     '0513',
#     '0514',
#     '0515',
#     '0516',
#     '0517',
#     '0518',
#     '0519',
#     '0520',
#     '0521',
#     '0522',
#     '0528',
#     '0529',
#     '0532',
#     '0533',
#     '0534',
#     '0536',
#     '0538',
#     '0540',
#     '0541',
#     '0542',
#     '0543',
#     '0544',
#     '0545',
#     '0599',
#     '06',
#     '38',
#     '3801',
#     '3802',
#     '3803',
#     '3804',
#     '3805',
#     '3806',
#     '3807',
#     '3808',
#     '3811',
#     '3812',
#     '3813',
#     '3814',
#     '3815',
#     '3816',
#     '3817',
#     '3818',
#     '3819',
#     '3820',
#     '3821',
#     '3822',
#     '3823',
#     '3824',
#     '3825',
#     '0601',
#     '0602',
#     '0604',
#     '0605',
#     '0612',
#     '0615',
#     '0616',
#     '0617',
#     '0618',
#     '0619',
#     '0620',
#     '0621',
#     '0622',
#     '0623',
#     '0624',
#     '0625',
#     '0626',
#     '0627',
#     '0628',
#     '0631',
#     '0632',
#     '0633',
#     '39',
#     '0699',
#     '3901',
#     '3903',
#     '3905',
#     '3907',
#     '3909',
#     '3911',
#     '40',
#     '4001',
#     '4003',
#     '4005',
#     '4010',
#     '4012',
#     '4014',
#     '4016',
#     '4018',
#     '4020',
#     '4022',
#     '4024',
#     '4026',
#     '4028',
#     '4030',
#     '4032',
#     '4034',
#     '4036',
#     '07',
#     '0701',
#     '0702',
#     '0703',
#     '0704',
#     '0705',
#     '0706',
#     '0707',
#     '0708',
#     '0709',
#     '0710',
#     '0711',
#     '0712',
#     '0713',
#     '0714',
#     '0715',
#     '0716',
#     '0716u',
#     '0717',
#     '0718',
#     '0719',
#     '0720',
#     '0721',
#     '0722',
#     '0723',
#     '0724',
#     '0725',
#     '0726',
#     '0727',
#     '0728',
#     '0729',
#     '0799',
#     '08',
#     '0805',
#     '0806',
#     '0807',
#     '0811',
#     '0814',
#     '0815',
#     '0817',
#     '0819',
#     '0821',
#     '0822',
#     '0826',
#     '0827',
#     '0828',
#     '0829',
#     '0830',
#     '0831',
#     '0833',
#     '0834',
#     '0899',
#     '42',
#     '09',
#     '4201',
#     '4202',
#     '4203',
#     '4204',
#     '4205',
#     '4206',
#     '4207',
#     '4211',
#     '4212',
#     '4213',
#     '4214',
#     '4215',
#     '4216',
#     '4217',
#     '4218',
#     '4219',
#     '4220',
#     '4221',
#     '4222',
#     '4223',
#     '4224',
#     '4225',
#     '4226',
#     '4227',
#     '4228',
#     '0901',
#     '0903',
#     '0904',
#     '0906',
#     '0911',
#     '0912',
#     '0914',
#     '0918',
#     '0919',
#     '0920',
#     '0921',
#     '0922',
#     '0923',
#     '0924',
#     '0926',
#     '0928',
#     '0929',
#     '0932',
#     '0933',
#     '0935',
#     '0937',
#     '0938',
#     '0940',
#     '0941',
#     '0999',
#     '10',
#     '1001',
#     '1002',
#     '1003',
#     '1004',
#     '1014',
#     '1017',
#     '1018',
#     '1021',
#     '1026',
#     '1027',
#     '1029',
#     '1032',
#     '1034',
#     '1037',
#     '1046',
#     '1099',
#     '11',
#     '1101',
#     '1102',
#     '1103',
#     '1106',
#     '1108',
#     '1111',
#     '1112',
#     '1114',
#     '1119',
#     '1120',
#     '1121',
#     '1122',
#     '1124',
#     '1127',
#     '1129',
#     '1130',
#     '1133',
#     '1134',
#     '1135',
#     '1141',
#     '1142',
#     '1144',
#     '1145',
#     '1146',
#     '1149',
#     '1151',
#     '1154',
#     '1159',
#     '1160',
#     '1199',
#     '46',
#     '12',
#     '4601',
#     '4602',
#     '4611',
#     '4612',
#     '4613',
#     '4614',
#     '4615',
#     '4616',
#     '4617',
#     '4618',
#     '4619',
#     '4620',
#     '4621',
#     '4622',
#     '4623',
#     '4624',
#     '4625',
#     '4626',
#     '4627',
#     '4628',
#     '4629',
#     '4630',
#     '4631',
#     '4632',
#     '4633',
#     '4634',
#     '4635',
#     '4636',
#     '4637',
#     '4638',
#     '4639',
#     '4640',
#     '4641',
#     '4642',
#     '4643',
#     '4644',
#     '4645',
#     '4646',
#     '4647',
#     '4648',
#     '4649',
#     '4650',
#     '4651',
#     '1201',
#     '1211',
#     '1214',
#     '1216',
#     '1219',
#     '1221',
#     '1222',
#     '1223',
#     '1224',
#     '1227',
#     '1228',
#     '1230',
#     '1231',
#     '1232',
#     '1233',
#     '1234',
#     '1235',
#     '1238',
#     '1241',
#     '1242',
#     '1243',
#     '1244',
#     '1245',
#     '1246',
#     '1247',
#     '1248',
#     '1249',
#     '1250',
#     '1251',
#     '1252',
#     '1253',
#     '1255',
#     '1256',
#     '1259',
#     '1260',
#     '1263',
#     '1264',
#     '1265',
#     '1266',
#     '1299',
#     '13',
#     '1301',
#     '14',
#     '1401',
#     '1411',
#     '1412',
#     '1413',
#     '1416',
#     '1417',
#     '1418',
#     '1419',
#     '1420',
#     '1421',
#     '1422',
#     '1424',
#     '1426',
#     '1428',
#     '1429',
#     '1430',
#     '1431',
#     '1432',
#     '1433',
#     '1438',
#     '1439',
#     '1441',
#     '1443',
#     '1444',
#     '1445',
#     '1448',
#     '1449',
#     '1499',
#     '15',
#     '1501',
#     '1502',
#     '1503',
#     '1504',
#     '1505',
#     '1506',
#     '1507',
#     '1508',
#     '1511',
#     '1514',
#     '1515',
#     '1516',
#     '1517',
#     '1519',
#     '1520',
#     '1523',
#     '1524',
#     '1525',
#     '1526',
#     '1527',
#     '1528',
#     '1529',
#     '1531',
#     '1532',
#     '1534',
#     '1535',
#     '1539',
#     '1543',
#     '1545',
#     '1546',
#     '1547',
#     '1548',
#     '1551',
#     '1554',
#     '1556',
#     '1557',
#     '1560',
#     '1563',
#     '1566',
#     '1567',
#     '1569',
#     '1571',
#     '1572',
#     '1573',
#     '1576',
#     '1577',
#     '1578',
#     '1579',
#     '1580',
#     '1599',
#     '50',
#     '16',
#     '5001',
#     '5004',
#     '5005',
#     '5006',
#     '5007',
#     '5011',
#     '5012',
#     '5013',
#     '5014',
#     '5015',
#     '5016',
#     '5017',
#     '5018',
#     '5019',
#     '5020',
#     '5021',
#     '5022',
#     '5023',
#     '5024',
#     '5025',
#     '5026',
#     '5027',
#     '5028',
#     '5029',
#     '5030',
#     '5031',
#     '5032',
#     '5033',
#     '5034',
#     '5035',
#     '5036',
#     '5037',
#     '5038',
#     '5039',
#     '5040',
#     '5041',
#     '5042',
#     '5043',
#     '5044',
#     '5045',
#     '5046',
#     '5047',
#     '5048',
#     '5049',
#     '5050',
#     '5051',
#     '5052',
#     '5053',
#     '5054',
#     '5055',
#     '5056',
#     '5057',
#     '5058',
#     '5059',
#     '5060',
#     '5061',
#     '1601',
#     '1612',
#     '1613',
#     '1617',
#     '1620',
#     '1621',
#     '1622',
#     '1624',
#     '1627',
#     '1630',
#     '1632',
#     '1633',
#     '1634',
#     '1635',
#     '1636',
#     '1638',
#     '1640',
#     '1644',
#     '1645',
#     '1648',
#     '1653',
#     '1657',
#     '1662',
#     '1663',
#     '1664',
#     '1665',
#     '1699',
#     '17',
#     '1702',
#     '1703',
#     '1711',
#     '1714',
#     '1717',
#     '1718',
#     '1719',
#     '1721',
#     '1723',
#     '1724',
#     '1725',
#     '1729',
#     '1736',
#     '1738',
#     '1739',
#     '1740',
#     '1742',
#     '1743',
#     '1744',
#     '1748',
#     '1749',
#     '1750',
#     '1751',
#     '1755',
#     '1756',
#     '1799',
#     '18',
#     '1804',
#     '1805',
#     '1806',
#     '1811',
#     '1812',
#     '1813',
#     '1814',
#     '1815',
#     '1816',
#     '1818',
#     '1820',
#     '1822',
#     '1824',
#     '1825',
#     '1826',
#     '1827',
#     '1828',
#     '1832',
#     '1833',
#     '1834',
#     '1835',
#     '1836',
#     '1837',
#     '1838',
#     '1839',
#     '1840',
#     '1841',
#     '1842',
#     '1843',
#     '1845',
#     '1848',
#     '1849',
#     '1850',
#     '1851',
#     '1852',
#     '1853',
#     '1854',
#     '1855',
#     '1856',
#     '1857',
#     '1858',
#     '1859',
#     '1860',
#     '1865',
#     '1866',
#     '1867',
#     '1868',
#     '1870',
#     '1871',
#     '1874',
#     '1875',
#     '55',
#     '56',
#     '1899',
#     '5501',
#     '5503',
#     '5510',
#     '5512',
#     '5514',
#     '5516',
#     '5518',
#     '5520',
#     '5522',
#     '5524',
#     '5526',
#     '5528',
#     '5530',
#     '5532',
#     '5534',
#     '5536',
#     '5538',
#     '5540',
#     '5542',
#     '5544',
#     '5546',
#     '5601',
#     '5603',
#     '5605',
#     '5607',
#     '5610',
#     '5612',
#     '5614',
#     '5616',
#     '5618',
#     '5620',
#     '5622',
#     '5624',
#     '5626',
#     '5628',
#     '5630',
#     '5632',
#     '5634',
#     '5636',
#     '54',
#     '19',
#     '5401',
#     '5402',
#     '5403',
#     '5404',
#     '5405',
#     '5406',
#     '5411',
#     '5412',
#     '5413',
#     '5414',
#     '5415',
#     '5416',
#     '5417',
#     '5418',
#     '5419',
#     '5420',
#     '5421',
#     '5422',
#     '5423',
#     '5424',
#     '5425',
#     '5426',
#     '5427',
#     '5428',
#     '5429',
#     '5430',
#     '5432',
#     '5433',
#     '5434',
#     '5435',
#     '5436',
#     '5437',
#     '5438',
#     '5439',
#     '5440',
#     '5441',
#     '5442',
#     '5443',
#     '5444',
#     '1901',
#     '1902',
#     '1903',
#     '1911',
#     '1913',
#     '1915',
#     '1917',
#     '1919',
#     '1920',
#     '1921',
#     '1922',
#     '1923',
#     '1924',
#     '1925',
#     '1926',
#     '1927',
#     '1928',
#     '1929',
#     '1931',
#     '1933',
#     '1936',
#     '1938',
#     '1939',
#     '1940',
#     '1941',
#     '1942',
#     '1943',
#     '1999',
#     '20',
#     '2001',
#     '2002',
#     '2003',
#     '2004',
#     '2011',
#     '2012',
#     '2014',
#     '2015',
#     '2016',
#     '2017',
#     '2018',
#     '2019',
#     '2020',
#     '2021',
#     '2022',
#     '2023',
#     '2024',
#     '2025',
#     '2027',
#     '2028',
#     '2030',
#     '2099',
#     '21',
#     '2101',
#     '2102',
#     '2103',
#     '2104',
#     '2105',
#     '2106',
#     '2107',
#     '2108',
#     '2109',
#     '2110',
#     '2111',
#     '2112',
#     '2113',
#     '2114',
#     '2115',
#     '2116',
#     '2117',
#     '2118',
#     '2119',
#     '2121',
#     '2131',
#     '2199',
#     '22',
#     '2211',
#     '2299',
#     '23',
#     '2300',
#     '2311',
#     '2321',
#     '2399',
#     '25',
#     '26',
#     '88',
#     '99',
#     '9999'],
#    'valueTexts': ['The whole country',
#     'Østfold',
#     'Halden',
#     'Moss',
#     'Sarpsborg',
#     'Fredrikstad',
#     'Hvaler',
#     'Råde',
#     'Våler (Østfold)',
#     'Skiptvet',
#     'Indre Østfold',
#     'Rakkestad',
#     'Marker',
#     'Aremark',
#     'Akershus',
#     'Bærum',
#     'Asker',
#     'Lillestrøm',
#     'Nordre Follo',
#     'Ullensaker',
#     'Nesodden',
#     'Frogn',
#     'Vestby',
#     'Ås',
#     'Enebakk',
#     'Lørenskog',
#     'Rælingen',
#     'Aurskog-Høland',
#     'Nes',
#     'Gjerdrum',
#     'Nittedal',
#     'Lunner',
#     'Jevnaker',
#     'Nannestad',
#     'Eidsvoll',
#     'Hurdal',
#     'Viken (2020-2023)',
#     'Østfold (-2019)',
#     'Halden (2020-2023)',
#     'Moss (2020-2023)',
#     'Sarpsborg (2020-2023)',
#     'Fredrikstad (2020-2023)',
#     'Drammen (2020-2023)',
#     'Kongsberg (2020-2023)',
#     'Ringerike (2020-2023)',
#     'Hvaler (2020-2023)',
#     'Aremark (2020-2023)',
#     'Marker (2020-2023)',
#     'Indre Østfold (2020-2023)',
#     'Skiptvet (2020-2023)',
#     'Rakkestad (2020-2023)',
#     'Råde (2020-2023)',
#     'Våler (Viken) (2020-2023)',
#     'Vestby (2020-2023)',
#     'Nordre Follo (2020-2023)',
#     'Ås (2020-2023)',
#     'Frogn (2020-2023)',
#     'Nesodden (2020-2023)',
#     'Bærum (2020-2023)',
#     'Asker (2020-2023)',
#     'Aurskog-Høland (2020-2023)',
#     'Rælingen (2020-2023)',
#     'Enebakk (2020-2023)',
#     'Lørenskog (2020-2023)',
#     'Lillestrøm (2020-2023)',
#     'Nittedal (2020-2023)',
#     'Gjerdrum (2020-2023)',
#     'Ullensaker (2020-2023)',
#     'Nes (2020-2023)',
#     'Eidsvoll (2020-2023)',
#     'Nannestad (2020-2023)',
#     'Hurdal (2020-2023)',
#     'Hole (2020-2023)',
#     'Flå (2020-2023)',
#     'Nesbyen (2020-2023)',
#     'Gol (2020-2023)',
#     'Hemsedal (2020-2023)',
#     'Ål (2020-2023)',
#     'Hol (2020-2023)',
#     'Sigdal (2020-2023)',
#     'Krødsherad (2020-2023)',
#     'Modum (2020-2023)',
#     'Øvre Eiker (2020-2023)',
#     'Lier (2020-2023)',
#     'Flesberg (2020-2023)',
#     'Rollag (2020-2023)',
#     'Nore og Uvdal (2020-2023)',
#     'Jevnaker (2020-2023)',
#     'Lunner (2020-2023)',
#     'Halden (-2019)',
#     'Sarpsborg (-1991)',
#     'Fredrikstad (-1993)',
#     'Moss (-2019)',
#     'Sarpsborg (1992-2019)',
#     'Fredrikstad (1994-2019)',
#     'Hvaler (-2019)',
#     'Borge (-1993)',
#     'Varteig (-1991)',
#     'Skjeberg (-1991)',
#     'Berg  (-1966)',
#     'Idd (-1966)',
#     'Aremark (-2019)',
#     'Marker (1964-2019)',
#     'Rømskog (-2019)',
#     'Trøgstad (-2019)',
#     'Spydeberg (-2019)',
#     'Askim (-2019)',
#     'Eidsberg (-2019)',
#     'Skiptvet (-2019)',
#     'Rakkestad (-2019)',
#     'Tune (-1991)',
#     'Rolvsøy (1911-1993)',
#     'Kråkerøy (1908-1993)',
#     'Onsøy (-1993)',
#     'Råde (-2019)',
#     'Rygge (-2019)',
#     'Våler (Østfold) (-2019)',
#     'Hobøl (-2019)',
#     'Unknown municipalities, Østfold',
#     'Akershus (-2019)',
#     'Vestby (-2019)',
#     'Ski (1931-2019)',
#     'Ås (-2019)',
#     'Frogn (-2019)',
#     'Nesodden (-2019)',
#     'Oppegård (1915-2019)',
#     'Bærum (-2019)',
#     'Asker (-2019)',
#     'Aurskog-Høland (1966-2019)',
#     'Sørum (-2019)',
#     'Fet (-2019)',
#     'Rælingen (1929-2019)',
#     'Enebakk (-2019)',
#     'Lørenskog (1908-2019)',
#     'Skedsmo (-2019)',
#     'Nittedal (-2019)',
#     'Gjerdrum (-2019)',
#     'Ullensaker (-2019)',
#     'Nes (Akershus) (-2019)',
#     'Eidsvoll (-2019)',
#     'Nannestad (-2019)',
#     'Hurdal (-2019)',
#     'Unknown municipalities, Akershus',
#     'Oslo',
#     'Oslo municipality',
#     'Buskerud',
#     'Uoppgitt komm. Oslo',
#     'Drammen',
#     'Kongsberg',
#     'Ringerike',
#     'Hole',
#     'Lier',
#     'Øvre Eiker',
#     'Modum',
#     'Krødsherad',
#     'Flå',
#     'Nesbyen',
#     'Gol',
#     'Hemsedal',
#     'Ål',
#     'Hol',
#     'Sigdal',
#     'Flesberg',
#     'Rollag',
#     'Nore og Uvdal',
#     'Innlandet',
#     'Hedmark (-2019)',
#     'Kongsvinger',
#     'Hamar',
#     'Lillehammer',
#     'Gjøvik',
#     'Ringsaker',
#     'Løten',
#     'Stange',
#     'Nord-Odal',
#     'Sør-Odal',
#     'Eidskog',
#     'Grue',
#     'Åsnes',
#     'Våler (Innlandet)',
#     'Elverum',
#     'Trysil',
#     'Åmot',
#     'Stor-Elvdal',
#     'Rendalen',
#     'Engerdal',
#     'Tolga',
#     'Tynset',
#     'Alvdal',
#     'Folldal',
#     'Os',
#     'Dovre',
#     'Lesja',
#     'Skjåk',
#     'Lom',
#     'Vågå',
#     'Nord-Fron',
#     'Sel',
#     'Sør-Fron',
#     'Ringebu',
#     'Øyer',
#     'Gausdal',
#     'Østre Toten',
#     'Vestre Toten',
#     'Gran',
#     'Søndre Land',
#     'Nordre Land',
#     'Sør-Aurdal',
#     'Etnedal',
#     'Nord-Aurdal',
#     'Vestre Slidre',
#     'Øystre Slidre',
#     'Vang',
#     'Hamar (-1991)',
#     'Kongsvinger (-2019)',
#     'Hamar (1992-2019)',
#     'Ringsaker (-2019)',
#     'Vang (-1991)',
#     'Løten (-2019)',
#     'Stange (-2019)',
#     'Nord-Odal (-2019)',
#     'Sør-Odal (-2019)',
#     'Eidskog (-2019)',
#     'Grue (-2019)',
#     'Åsnes (-2019)',
#     'Våler (Hedmark) (-2019)',
#     'Elverum (-2019)',
#     'Trysil (-2019)',
#     'Åmot (-2019)',
#     'Stor-Elvdal (-2019)',
#     'Rendalen (1965-2019)',
#     'Engerdal (1911-2019)',
#     'Tolga-Os (1966-1975)',
#     'Tolga (-2019)',
#     'Tynset (-2019)',
#     'Alvdal (-2019)',
#     'Folldal (1914-2019)',
#     'Os (Hedmark) (1976-2019)',
#     'Unknown municipalities, Hedmark',
#     'Oppland (-2019)',
#     'Lillehammer (-2019)',
#     'Gjøvik (-2019)',
#     'Dovre (-2019)',
#     'Lesja (-2019)',
#     'Skjåk (-2019)',
#     'Lom (-2019)',
#     'Vågå (-2019)',
#     'Nord-Fron (1977-2019)',
#     'Sel (1908-2019)',
#     'Fron (1966-1976)',
#     'Sør-Fron (-2019)',
#     'Ringebu (-2019)',
#     'Øyer (-2019)',
#     'Gausdal (1962-2019)',
#     'Østre Toten (-2019)',
#     'Vestre Toten (-2019)',
#     'Jevnaker (-2019)',
#     'Lunner (-2019)',
#     'Gran (-2019)',
#     'Søndre Land (-2019)',
#     'Nordre Land (-2019)',
#     'Sør-Aurdal (-2019)',
#     'Etnedal (-2019)',
#     'Nord-Aurdal (-2019)',
#     'Vestre Slidre (-2019)',
#     'Øystre Slidre (-2019)',
#     'Vang (-2019)',
#     'Unknown municipalities, Oppland',
#     'Buskerud (-2019)',
#     'Vestfold og Telemark (2020-2023)',
#     'Horten (2020-2023)',
#     'Holmestrand (2020-2023)',
#     'Tønsberg (2020-2023)',
#     'Sandefjord (2020-2023)',
#     'Larvik (2020-2023)',
#     'Porsgrunn (2020-2023)',
#     'Skien (2020-2023)',
#     'Notodden (2020-2023)',
#     'Færder (2020-2023)',
#     'Siljan (2020-2023)',
#     'Bamble (2020-2023)',
#     'Kragerø (2020-2023)',
#     'Drangedal (2020-2023)',
#     'Nome (2020-2023)',
#     'Midt-Telemark (2020-2023)',
#     'Tinn (2020-2023)',
#     'Hjartdal (2020-2023)',
#     'Seljord (2020-2023)',
#     'Kviteseid (2020-2023)',
#     'Nissedal (2020-2023)',
#     'Fyresdal (2020-2023)',
#     'Tokke (2020-2023)',
#     'Vinje (2020-2023)',
#     'Ringerike (1964-1976)',
#     'Drammen (-2019)',
#     'Kongsberg (-2019)',
#     'Ringerike (1977-2019)',
#     'Hole (1977-2019)',
#     'Flå (-2019)',
#     'Nes (Buskerud) (-2019)',
#     'Gol (-2019)',
#     'Hemsedal (-2019)',
#     'Ål (-2019)',
#     'Hol (-2019)',
#     'Sigdal (-2019)',
#     'Krødsherad (-2019)',
#     'Modum (-2019)',
#     'Øvre Eiker (-2019)',
#     'Nedre Eiker (-2019)',
#     'Lier (-2019)',
#     'Røyken (-2019)',
#     'Hurum (-2019)',
#     'Flesberg (-2019)',
#     'Rollag (-2019)',
#     'Nore og Uvdal (1962-2019)',
#     'Vestfold',
#     'Unknown municipalities, Buskerud',
#     'Horten',
#     'Holmestrand',
#     'Tønsberg',
#     'Sandefjord',
#     'Larvik',
#     'Færder',
#     'Telemark',
#     'Porsgrunn',
#     'Skien',
#     'Notodden',
#     'Siljan',
#     'Bamble',
#     'Kragerø',
#     'Drangedal',
#     'Nome',
#     'Midt-Telemark',
#     'Seljord',
#     'Hjartdal',
#     'Tinn',
#     'Kviteseid',
#     'Nissedal',
#     'Fyresdal',
#     'Tokke',
#     'Vinje',
#     'Vestfold (-2019)',
#     'Horten (2002-2019)',
#     'Holmestrand (-2017)',
#     'Horten (-1987)',
#     'Tønsberg (1988-2019)',
#     'Tønsberg (-1987)',
#     'Sandefjord (-2016)',
#     'Larvik (-1987)',
#     'Stavern (1944-1987)',
#     'Larvik (1988-2017)',
#     'Sandefjord (2017-2019)',
#     'Svelvik (1964-2019)',
#     'Larvik (2018-2019)',
#     'Sande (Vestfold) (-2019)',
#     'Hof (-2017)',
#     'Holmestrand (2018-2019)',
#     'Re (2002-2019)',
#     'Våle (-2001)',
#     'Borre (-1987)',
#     'Ramnes (-2001)',
#     'Andebu (-2016)',
#     'Stokke (-2016)',
#     'Sem (-1987)',
#     'Nøtterøy (-2017)',
#     'Tjøme (-2017)',
#     'Sandar (-1967)',
#     'Tjølling (-1987)',
#     'Brunlanes (-1987)',
#     'Hedrum (-1987)',
#     'Lardal (-2017)',
#     'Færder (2018-2019)',
#     'Unknown municipalities, Vestfold',
#     'Telemark (-2019)',
#     'Porsgrunn (-2019)',
#     'Skien (-2019)',
#     'Notodden (1913-2019)',
#     'Siljan (-2019)',
#     'Bamble (-2019)',
#     'Kragerø (1960-2019)',
#     'Drangedal (-2019)',
#     'Nome (1964-2019)',
#     'Bø (Telemark) (-2019)',
#     'Sauherad (-2019)',
#     'Tinn (-2019)',
#     'Hjartdal (-2019)',
#     'Seljord (-2019)',
#     'Kviteseid (-2019)',
#     'Nissedal (-2019)',
#     'Fyresdal (-2019)',
#     'Tokke (1964-2019)',
#     'Vinje (-2019)',
#     'Unknown municipalities, Telemark',
#     'Agder',
#     'Aust-Agder (-2019)',
#     'Risør',
#     'Grimstad',
#     'Arendal',
#     'Kristiansand',
#     'Lindesnes',
#     'Farsund',
#     'Flekkefjord',
#     'Gjerstad',
#     'Vegårshei',
#     'Tvedestrand',
#     'Froland',
#     'Lillesand',
#     'Birkenes',
#     'Åmli',
#     'Iveland',
#     'Evje og Hornnes',
#     'Bygland',
#     'Valle',
#     'Bykle',
#     'Vennesla',
#     'Åseral',
#     'Lyngdal',
#     'Hægebostad',
#     'Kvinesdal',
#     'Sirdal',
#     'Risør (-2019)',
#     'Arendal (-1991)',
#     'Grimstad (-2019)',
#     'Arendal (1992-2019)',
#     'Gjerstad (-2019)',
#     'Vegårshei (-2019)',
#     'Tvedestrand (-2019)',
#     'Moland (1962-1991)',
#     'Froland (-2019)',
#     'Øyestad (-1991)',
#     'Tromøy (-1991)',
#     'Hisøy (-1991)',
#     'Fjære (-1970)',
#     'Landvik (-1970)',
#     'Lillesand (1962-2019)',
#     'Birkenes (-2019)',
#     'Åmli (-2019)',
#     'Mykland (-1966)',
#     'Herefoss (-1966)',
#     'Iveland (-2019)',
#     'Evje og Hornnes (1960-2019)',
#     'Bygland (-2019)',
#     'Valle (-2019)',
#     'Bykle (-2019)',
#     'Unknown municipalities, Aust-Agder',
#     'Vest-Agder (-2019)',
#     'Kristiansand (-2019)',
#     'Mandal (-2019)',
#     'Farsund (-2019)',
#     'Flekkefjord (-2019)',
#     'Vennesla (-2019)',
#     'Songdalen (1964-2019)',
#     'Søgne (-2019)',
#     'Marnardal (1964-2019)',
#     'Åseral (-2019)',
#     'Audnedal (1964-2019)',
#     'Lindesnes (1964-2019)',
#     'Lyngdal (-2019)',
#     'Hægebostad (-2019)',
#     'Kvinesdal (-2019)',
#     'Sirdal (1960-2019)',
#     'Unknown municipalities, Vest-Agder',
#     'Rogaland',
#     'Eigersund',
#     'Sandnes (-2019)',
#     'Stavanger',
#     'Haugesund',
#     'Sandnes',
#     'Sokndal',
#     'Lund',
#     'Bjerkreim',
#     'Hå',
#     'Klepp',
#     'Time',
#     'Gjesdal',
#     'Sola',
#     'Randaberg',
#     'Forsand (-2019)',
#     'Strand',
#     'Hjelmeland',
#     'Suldal',
#     'Sauda',
#     'Finnøy (-2019)',
#     'Rennesøy (-2019)',
#     'Kvitsøy',
#     'Bokn',
#     'Tysvær',
#     'Karmøy',
#     'Utsira',
#     'Vindafjord (1965-2005)',
#     'Ølen (2002-2005)',
#     'Vindafjord',
#     'Unknown municipalities, Rogaland',
#     'Vestland',
#     'Hordaland (-2019)',
#     'Bergen',
#     'Kinn',
#     'Etne',
#     'Sveio',
#     'Bømlo',
#     'Stord',
#     'Fitjar',
#     'Tysnes',
#     'Kvinnherad',
#     'Ullensvang',
#     'Eidfjord',
#     'Ulvik',
#     'Voss',
#     'Kvam',
#     'Samnanger',
#     'Bjørnafjorden',
#     'Austevoll',
#     'Øygarden',
#     'Askøy',
#     'Vaksdal',
#     'Modalen',
#     'Osterøy',
#     'Alver',
#     'Austrheim',
#     'Fedje',
#     'Masfjorden',
#     'Gulen',
#     'Solund',
#     'Hyllestad',
#     'Høyanger',
#     'Vik',
#     'Sogndal',
#     'Aurland',
#     'Lærdal',
#     'Årdal',
#     'Luster',
#     'Askvoll',
#     'Fjaler',
#     'Sunnfjord',
#     'Bremanger',
#     'Stad',
#     'Gloppen',
#     'Stryn',
#     'Bergen (1972-2019)',
#     'Etne (-2019)',
#     'Ølen (1916-2001)',
#     'Sveio (-2019)',
#     'Bømlo (1916-2019)',
#     'Stord (-2019)',
#     'Fitjar (-2019)',
#     'Tysnes (-2019)',
#     'Kvinnherad (-2019)',
#     'Jondal (-2019)',
#     'Odda (1913-2019)',
#     'Ullensvang (-1976)',
#     'Ullensvang (1977-2019)',
#     'Eidfjord (-2019)',
#     'Ulvik (-2019)',
#     'Granvin (-2019)',
#     'Voss (-2019)',
#     'Kvam (-2019)',
#     'Fusa (-2019)',
#     'Samnanger (1907-2019)',
#     'Os (Hordaland) (-2019)',
#     'Austevoll (-2019)',
#     'Sund (-2019)',
#     'Fjell (-2019)',
#     'Askøy (-2019)',
#     'Laksevåg (1918-1971)',
#     'Fana (-1971)',
#     'Arna (1964-1971)',
#     'Vaksdal (1964-2019)',
#     'Modalen (1910-2019)',
#     'Osterøy (1964-2019)',
#     'Åsane (-1971)',
#     'Meland (1924-2019)',
#     'Øygarden (1964-2019)',
#     'Radøy (1964-2019)',
#     'Lindås (-2019)',
#     'Austrheim (1910-2019)',
#     'Fedje (1948-2019)',
#     'Masfjorden (-2019)',
#     'Unknown municipalities, Hordaland',
#     'Bergen (-1971)',
#     'Bergen (-1971)',
#     'Sogn og Fjordane (-2019)',
#     'Flora (1964-2019)',
#     'Gulen (-2019)',
#     'Solund (-2019)',
#     'Hyllestad (-2019)',
#     'Høyanger (1964-2019)',
#     'Vik (-2019)',
#     'Balestrand (-2019)',
#     'Leikanger (-2019)',
#     'Sogndal (-2019)',
#     'Aurland (-2019)',
#     'Lærdal (-2019)',
#     'Årdal (-2019)',
#     'Luster (-2019)',
#     'Askvoll (-2019)',
#     'Fjaler (-2019)',
#     'Gaular (-2019)',
#     'Jølster (-2019)',
#     'Førde (-2019)',
#     'Naustdal (-2019)',
#     'Bremanger (-2019)',
#     'Vågsøy (1964-2019)',
#     'Selje (-2019)',
#     'Eid (-2019)',
#     'Hornindal (-2019)',
#     'Gloppen (-2019)',
#     'Stryn (-1976)',
#     'Stryn (1977-2019)',
#     'Unknown municipalities, Sogn og Fjordane',
#     'Møre og Romsdal',
#     'Ålesund (-1976)',
#     'Molde (-2019)',
#     'Kristiansund  (-2007)',
#     'Ålesund (1977-2019)',
#     'Kristiansund',
#     'Molde',
#     'Ålesund (2020-2023)',
#     'Ålesund',
#     'Vanylven',
#     'Sande',
#     'Herøy (Møre og Romsdal)',
#     'Ulstein',
#     'Hareid',
#     'Volda (-2019)',
#     'Ørsta',
#     'Ørskog (1977-2019)',
#     'Norddal (-2019)',
#     'Stranda',
#     'Stordal (-2019)',
#     'Ørskog (-1976)',
#     'Sykkylven',
#     'Skodje (-2019)',
#     'Sula',
#     'Giske',
#     'Haram (-2019)',
#     'Vestnes',
#     'Rauma',
#     'Nesset (-2019)',
#     'Midsund (1965-2019)',
#     'Sandøy (-2019)',
#     'Aukra',
#     'Fræna (-2019)',
#     'Eide (-2019)',
#     'Averøy',
#     'Frei (-2007)',
#     'Gjemnes',
#     'Tingvoll',
#     'Sunndal',
#     'Surnadal',
#     'Rindal (-2018)',
#     'Aure (-2005)',
#     'Halsa (-2019)',
#     'Tustna (-2005)',
#     'Smøla',
#     'Aure',
#     'Volda',
#     'Fjord',
#     'Hustadvika',
#     'Haram',
#     'Unknown municipalities, Møre og Romsdal',
#     'Trøndelag - Trööndelage',
#     'Sør-Trøndelag (-2017)',
#     'Trondheim - Tråante',
#     'Steinkjer (2018-2019)',
#     'Namsos (2018-2019)',
#     'Steinkjer',
#     'Namsos - Nåavmesjenjaelmie',
#     'Hemne (2018-2019)',
#     'Snillfjord (2018-2019)',
#     'Hitra (2018-2019)',
#     'Frøya',
#     'Ørland (2018-2019)',
#     'Agdenes (2018-2019)',
#     'Bjugn (2018-2019)',
#     'Åfjord (2018-2019)',
#     'Roan (2018-2019)',
#     'Osen',
#     'Oppdal',
#     'Rennebu',
#     'Meldal (2018-2019)',
#     'Orkdal (2018-2019)',
#     'Røros - Rosse',
#     'Holtålen',
#     'Midtre Gauldal',
#     'Melhus',
#     'Skaun',
#     'Klæbu (2018-2019)',
#     'Malvik',
#     'Selbu',
#     'Tydal',
#     'Meråker',
#     'Stjørdal',
#     'Frosta',
#     'Levanger - Levangke',
#     'Verdal',
#     'Verran (2018-2019)',
#     'Namdalseid (2018-2019)',
#     'Snåase - Snåsa',
#     'Lierne',
#     'Raarvihke - Røyrvik',
#     'Namsskogan',
#     'Grong',
#     'Høylandet',
#     'Overhalla',
#     'Fosnes (2018-2019)',
#     'Flatanger',
#     'Vikna (2018-2019)',
#     'Nærøy (2018-2019)',
#     'Leka',
#     'Inderøy',
#     'Indre Fosen',
#     'Heim',
#     'Hitra',
#     'Ørland',
#     'Åfjord',
#     'Orkland',
#     'Nærøysund',
#     'Rindal',
#     'Trondheim (-2017)',
#     'Hemne (-2017)',
#     'Snillfjord (1924-2017)',
#     'Hitra (-2017)',
#     'Frøya (1964-2017)',
#     'Ørland (-2017)',
#     'Agdenes (-2017)',
#     'Rissa (-2017)',
#     'Bjugn (-2017)',
#     'Åfjord (-2017)',
#     'Roan (-2017)',
#     'Osen (-2017)',
#     'Oppdal (-2017)',
#     'Rennebu (-2017)',
#     'Meldal (-2017)',
#     'Orkdal (-2017)',
#     'Røros (-2017)',
#     'Holtålen (1972-2017)',
#     'Haltdalen (-1971)',
#     'Midtre Gauldal (1964-2017)',
#     'Melhus (-2017)',
#     'Skaun (-2017)',
#     'Klæbu (-2017)',
#     'Malvik (-2017)',
#     'Selbu (-2017)',
#     'Tydal (-2017)',
#     'Unknown municipalities, Sør-Trøndelag',
#     'Nord-Trøndelag (-2017)',
#     'Steinkjer (-2017)',
#     'Namsos (-2017)',
#     'Meråker (-2017)',
#     'Stjørdal (-2017)',
#     'Frosta (-2017)',
#     'Leksvik (-2017)',
#     'Levanger (1962-2017)',
#     'Verdal (-2017)',
#     'Mosvik  (-2011)',
#     'Verran (-2017)',
#     'Namdalseid (-2017)',
#     'Inderøy (-2011)',
#     'Snåase - Snåsa (-2017)',
#     'Lierne (1964-2017)',
#     'Raarvihke - Røyrvik (1923-2017)',
#     'Namsskogan (1923-2017)',
#     'Grong (-2017)',
#     'Høylandet (-2017)',
#     'Overhalla (-2017)',
#     'Fosnes (-2017)',
#     'Flatanger (-2017)',
#     'Vikna (-2017)',
#     'Nærøy (-2017)',
#     'Leka (-2017)',
#     'Inderøy (2012-2017)',
#     'Unknown municipalities, Nord-Trøndelag',
#     'Nordland - Nordlánnda',
#     'Bodø',
#     'Narvik (-2019)',
#     'Narvik',
#     'Bindal',
#     'Sømna',
#     'Brønnøy',
#     'Brønnøy (-1976)',
#     'Vega',
#     'Vevelstad',
#     'Herøy (Nordland)',
#     'Alstahaug',
#     'Leirfjord',
#     'Vefsn',
#     'Grane',
#     'Aarborte - Hattfjelldal',
#     'Dønna',
#     'Nesna',
#     'Hemnes',
#     'Rana - Raane',
#     'Lurøy',
#     'Træna',
#     'Rødøy',
#     'Meløy',
#     'Gildeskål',
#     'Beiarn',
#     'Saltdal',
#     'Fauske - Fuosko',
#     'Skjerstad (-2004)',
#     'Bodin (-1967)',
#     'Sørfold - Fuolldá',
#     'Steigen',
#     'Hamarøy - Hábmer (-2019)',
#     'Divtasvuodna - Tysfjord (-2019)',
#     'Lødingen',
#     'Tjeldsund (1909-2019)',
#     'Evenes - Evenássi',
#     'Ballangen (1925-2019)',
#     'Ankenes (-1973)',
#     'Røst',
#     'Værøy',
#     'Moskenes (1916-1975)',
#     'Flakstad',
#     'Vestvågøy',
#     'Vågan',
#     'Hadsel',
#     'Bø (Nordland)',
#     'Øksnes',
#     'Sortland - Suortá',
#     'Andøy',
#     'Moskenes',
#     'Hábmer - Hamarøy',
#     'Troms - Romsa - Tromssa',
#     'Finnmark - Finnmárku - Finmarkku',
#     'Unknown municipalities, Nordland',
#     'Tromsø',
#     'Harstad - Hárstták',
#     'Kvæfjord',
#     'Dielddanuorri - Tjeldsund',
#     'Ibestad',
#     'Gratangen - Rivtták',
#     'Loabák - Lavangen',
#     'Bardu',
#     'Salangen',
#     'Målselv',
#     'Sørreisa',
#     'Dyrøy',
#     'Senja',
#     'Balsfjord',
#     'Karlsøy',
#     'Lyngen',
#     'Storfjord - Omasvuotna - Omasvuono',
#     'Gáivuotna - Kåfjord - Kaivuono',
#     'Skjervøy',
#     'Nordreisa - Ráisa - Raisi',
#     'Kvænangen',
#     'Alta',
#     'Hammerfest - Hámmerfeasta',
#     'Sør-Varanger',
#     'Vadsø',
#     'Kárásjohka - Karasjok',
#     'Guovdageaidnu - Kautokeino',
#     'Loppa',
#     'Hasvik',
#     'Måsøy',
#     'Nordkapp',
#     'Porsanger - Porsángu - Porsanki',
#     'Lebesby',
#     'Gamvik',
#     'Deatnu - Tana',
#     'Berlevåg',
#     'Båtsfjord',
#     'Vardø',
#     'Unjárga - Nesseby',
#     'Troms og Finnmark - Romsa ja Finnmárku (2020-2023)',
#     'Troms - Romsa (-2019)',
#     'Tromsø (2020-2023)',
#     'Harstad - Hárstták (2020-2023)',
#     'Alta (2020-2023)',
#     'Vardø (2020-2023)',
#     'Vadsø (2020-2023)',
#     'Hammerfest - Hámmerfeasta (2020-2023)',
#     'Kvæfjord (2020-2023)',
#     'Dielddanuorri - Tjeldsund (2020-2023)',
#     'Ibestad (2020-2023)',
#     'Gratangen (2020-2023)',
#     'Loabák - Lavangen (2020-2023)',
#     'Bardu (2020-2023)',
#     'Salangen (2020-2023)',
#     'Målselv (2020-2023)',
#     'Sørreisa (2020-2023)',
#     'Dyrøy (2020-2023)',
#     'Senja (2020-2023)',
#     'Balsfjord (2020-2023)',
#     'Karlsøy (2020-2023)',
#     'Lyngen (2020-2023)',
#     'Storfjord - Omasvuotna - Omasvuono (2020-2023)',
#     'Gáivuotna - Kåfjord - Kaivuono (2020-2023)',
#     'Skjervøy (2020-2023)',
#     'Nordreisa - Ráisa - Raisi (2020-2023)',
#     'Kvænangen (2020-2023)',
#     'Guovdageaidnu - Kautokeino (2020-2023)',
#     'Loppa (2020-2023)',
#     'Hasvik (2020-2023)',
#     'Måsøy (2020-2023)',
#     'Nordkapp (2020-2023)',
#     'Porsanger - Porsángu - Porsanki (2020-2023)',
#     'Kárásjohka - Karasjok (2020-2023)',
#     'Lebesby (2020-2023)',
#     'Gamvik (2020-2023)',
#     'Berlevåg (2020-2023)',
#     'Deatnu - Tana (2020-2023)',
#     'Unjárga - Nesseby (2020-2023)',
#     'Båtsfjord (2020-2023)',
#     'Sør-Varanger (2020-2023)',
#     'Harstad (-2012)',
#     'Tromsø (-2019)',
#     'Harstad - Hárstták (2013-2019)',
#     'Kvæfjord (-2019)',
#     'Skånland (1926-2019)',
#     'Bjarkøy (-2012)',
#     'Ibestad (-2019)',
#     'Gratangen (1926-2019)',
#     'Loabák - Lavangen (1907-2019)',
#     'Salangen (-1976)',
#     'Bardu (-2019)',
#     'Salangen (1977-2019)',
#     'Målselv (-2019)',
#     'Sørreisa (-2019)',
#     'Dyrøy (-2019)',
#     'Tranøy (-2019)',
#     'Torsken (-2019)',
#     'Berg (-2019)',
#     'Lenvik (-2019)',
#     'Balsfjord (-2019)',
#     'Karlsøy (-2019)',
#     'Lyngen (-2019)',
#     'Storfjord - Omasvuotna - Omasvuono (1931-2019)',
#     'Gáivuotna - Kåfjord - Kaivuono (1931-2019)',
#     'Skjervøy (-2019)',
#     'Nordreisa - Ráisa - Raisi (-2019)',
#     'Kvænangen (-2019)',
#     'Unknown municipalities, Troms',
#     'Finnmark - Finnmárku (-2019)',
#     'Hammerfest (-1991)',
#     'Vardø (-2019)',
#     'Vadsø (-2019)',
#     'Hammerfest (1992-2019)',
#     'Guovdageaidnu - Kautokeino (-2019)',
#     'Alta (-2019)',
#     'Loppa (-2019)',
#     'Hasvik (-2019)',
#     'Sørøysund (-1991)',
#     'Kvalsund (-2019)',
#     'Måsøy (-2019)',
#     'Nordkapp (-2019)',
#     'Porsanger - Porsángu - Porsanki (1964-2019)',
#     'Kárásjohka - Karasjok (-2019)',
#     'Lebesby (-2019)',
#     'Gamvik (1914-2019)',
#     'Berlevåg (1914-2019)',
#     'Deatnu - Tana (-2019)',
#     'Unjárga - Nesseby (-2019)',
#     'Båtsfjord (1955-2019)',
#     'Sør-Varanger (-2019)',
#     'Unknown municipalities, Finnmark',
#     'Svalbard',
#     'Colesbukta planning area',
#     'Pyramiden planning area',
#     'Van Mijenfjorden',
#     'Nordenskiöld Land nationalpark',
#     'Isfjorden',
#     'Sassen-Bünsow Land nationalpark',
#     'Nordre Isfjorden nationalpark',
#     'Kongsfjorden',
#     'Forlandet nationalpark',
#     'Wijdefjorden',
#     'Longyearbyen planning area',
#     'Ny-Ålesund planning area',
#     'Barentsburg planning area',
#     'Sør-Spitsbergen nationalpark',
#     'Sveagruva planning area',
#     'Indre Wijdefjorden nationalpark',
#     'Nordvest-Spitsbergen nationalpark',
#     'Nordaust-Svalbard naturereserve',
#     'Søraust-Svalbard naturereserve',
#     'Bjørnøya naturereserve',
#     'Hopen naturereserve',
#     'Unknown munipalities in Svalbard',
#     'Jan Mayen',
#     'Jan Mayen',
#     'Unknown  in Jan Mayen',
#     'The Continental Shelf',
#     'Continental shelf',
#     'The continental shelf south of 62 degrees north latitude',
#     'The continental shelf north of 62 degrees north latitude',
#     'The continental shelf, unspecified',
#     'Abroad',
#     'Ocean areas',
#     'Not resident in Norway',
#     'County not stated',
#     'Unknown municipality'],
#    'elimination': True},
#   {'code': 'TettSpredt',
#    'text': 'densely/sparsely populated areas',
#    'values': ['10', '11', '12'],
#    'valueTexts': ['Densely populated area',
#     'Sparsley populated area',
#     'Unknown'],
#    'elimination': True},
#   {'code': 'Kjonn',
#    'text': 'sex',
#    'values': ['2', '1'],
#    'valueTexts': ['Females', 'Males'],
#    'elimination': True},
#   {'code': 'ContentsCode',
#    'text': 'contents',
#    'values': ['Folkemengde'],
#    'valueTexts': ['Population']},
#   {'code': 'Tid',
#    'text': 'year',
#    'values': ['1990',
#     '1991',
#     '1992',
#     '1993',
#     '1994',
#     '1995',
#     '1996',
#     '1997',
#     '1998',
#     '1999',
#     '2000',
#     '2001',
#     '2002',
#     '2003',
#     '2004',
#     '2005',
#     '2006',
#     '2007',
#     '2008',
#     '2009',
#     '2011',
#     '2012',
#     '2013',
#     '2014',
#     '2015',
#     '2016',
#     '2017',
#     '2018',
#     '2019',
#     '2020',
#     '2021',
#     '2022',
#     '2023',
#     '2024'],
#    'valueTexts': ['1990',
#     '1991',
#     '1992',
#     '1993',
#     '1994',
#     '1995',
#     '1996',
#     '1997',
#     '1998',
#     '1999',
#     '2000',
#     '2001',
#     '2002',
#     '2003',
#     '2004',
#     '2005',
#     '2006',
#     '2007',
#     '2008',
#     '2009',
#     '2011',
#     '2012',
#     '2013',
#     '2014',
#     '2015',
#     '2016',
#     '2017',
#     '2018',
#     '2019',
#     '2020',
#     '2021',
#     '2022',
#     '2023',
#     '2024'],
#    'time': True}]}

# %% [markdown]
# Note how the metadata differs from previous nodes: The keyword variables is there, which indicates that we are in a leaf node. From here we can therefore fetch the actual data.
#
# ---
#
# It is not necessary to call info() after each go_down() but it is a good idea to do anyway, if you are not very sure of what the database looks like.

# %% [markdown]
# # Fetch data

# %% [markdown]
# Now that we are in a leaf node we can look at which variables there are, and their respective ranges:

# %%
ssb.get_variables()
# Out:
# {'region': ['The whole country',
#   'Østfold',
#   'Halden',
#   'Moss',
#   'Sarpsborg',
#   'Fredrikstad',
#   'Hvaler',
#   'Råde',
#   'Våler (Østfold)',
#   'Skiptvet',
#   'Indre Østfold',
#   'Rakkestad',
#   'Marker',
#   'Aremark',
#   'Akershus',
#   'Bærum',
#   'Asker',
#   'Lillestrøm',
#   'Nordre Follo',
#   'Ullensaker',
#   'Nesodden',
#   'Frogn',
#   'Vestby',
#   'Ås',
#   'Enebakk',
#   'Lørenskog',
#   'Rælingen',
#   'Aurskog-Høland',
#   'Nes',
#   'Gjerdrum',
#   'Nittedal',
#   'Lunner',
#   'Jevnaker',
#   'Nannestad',
#   'Eidsvoll',
#   'Hurdal',
#   'Viken (2020-2023)',
#   'Østfold (-2019)',
#   'Halden (2020-2023)',
#   'Moss (2020-2023)',
#   'Sarpsborg (2020-2023)',
#   'Fredrikstad (2020-2023)',
#   'Drammen (2020-2023)',
#   'Kongsberg (2020-2023)',
#   'Ringerike (2020-2023)',
#   'Hvaler (2020-2023)',
#   'Aremark (2020-2023)',
#   'Marker (2020-2023)',
#   'Indre Østfold (2020-2023)',
#   'Skiptvet (2020-2023)',
#   'Rakkestad (2020-2023)',
#   'Råde (2020-2023)',
#   'Våler (Viken) (2020-2023)',
#   'Vestby (2020-2023)',
#   'Nordre Follo (2020-2023)',
#   'Ås (2020-2023)',
#   'Frogn (2020-2023)',
#   'Nesodden (2020-2023)',
#   'Bærum (2020-2023)',
#   'Asker (2020-2023)',
#   'Aurskog-Høland (2020-2023)',
#   'Rælingen (2020-2023)',
#   'Enebakk (2020-2023)',
#   'Lørenskog (2020-2023)',
#   'Lillestrøm (2020-2023)',
#   'Nittedal (2020-2023)',
#   'Gjerdrum (2020-2023)',
#   'Ullensaker (2020-2023)',
#   'Nes (2020-2023)',
#   'Eidsvoll (2020-2023)',
#   'Nannestad (2020-2023)',
#   'Hurdal (2020-2023)',
#   'Hole (2020-2023)',
#   'Flå (2020-2023)',
#   'Nesbyen (2020-2023)',
#   'Gol (2020-2023)',
#   'Hemsedal (2020-2023)',
#   'Ål (2020-2023)',
#   'Hol (2020-2023)',
#   'Sigdal (2020-2023)',
#   'Krødsherad (2020-2023)',
#   'Modum (2020-2023)',
#   'Øvre Eiker (2020-2023)',
#   'Lier (2020-2023)',
#   'Flesberg (2020-2023)',
#   'Rollag (2020-2023)',
#   'Nore og Uvdal (2020-2023)',
#   'Jevnaker (2020-2023)',
#   'Lunner (2020-2023)',
#   'Halden (-2019)',
#   'Sarpsborg (-1991)',
#   'Fredrikstad (-1993)',
#   'Moss (-2019)',
#   'Sarpsborg (1992-2019)',
#   'Fredrikstad (1994-2019)',
#   'Hvaler (-2019)',
#   'Borge (-1993)',
#   'Varteig (-1991)',
#   'Skjeberg (-1991)',
#   'Berg  (-1966)',
#   'Idd (-1966)',
#   'Aremark (-2019)',
#   'Marker (1964-2019)',
#   'Rømskog (-2019)',
#   'Trøgstad (-2019)',
#   'Spydeberg (-2019)',
#   'Askim (-2019)',
#   'Eidsberg (-2019)',
#   'Skiptvet (-2019)',
#   'Rakkestad (-2019)',
#   'Tune (-1991)',
#   'Rolvsøy (1911-1993)',
#   'Kråkerøy (1908-1993)',
#   'Onsøy (-1993)',
#   'Råde (-2019)',
#   'Rygge (-2019)',
#   'Våler (Østfold) (-2019)',
#   'Hobøl (-2019)',
#   'Unknown municipalities, Østfold',
#   'Akershus (-2019)',
#   'Vestby (-2019)',
#   'Ski (1931-2019)',
#   'Ås (-2019)',
#   'Frogn (-2019)',
#   'Nesodden (-2019)',
#   'Oppegård (1915-2019)',
#   'Bærum (-2019)',
#   'Asker (-2019)',
#   'Aurskog-Høland (1966-2019)',
#   'Sørum (-2019)',
#   'Fet (-2019)',
#   'Rælingen (1929-2019)',
#   'Enebakk (-2019)',
#   'Lørenskog (1908-2019)',
#   'Skedsmo (-2019)',
#   'Nittedal (-2019)',
#   'Gjerdrum (-2019)',
#   'Ullensaker (-2019)',
#   'Nes (Akershus) (-2019)',
#   'Eidsvoll (-2019)',
#   'Nannestad (-2019)',
#   'Hurdal (-2019)',
#   'Unknown municipalities, Akershus',
#   'Oslo',
#   'Oslo municipality',
#   'Buskerud',
#   'Uoppgitt komm. Oslo',
#   'Drammen',
#   'Kongsberg',
#   'Ringerike',
#   'Hole',
#   'Lier',
#   'Øvre Eiker',
#   'Modum',
#   'Krødsherad',
#   'Flå',
#   'Nesbyen',
#   'Gol',
#   'Hemsedal',
#   'Ål',
#   'Hol',
#   'Sigdal',
#   'Flesberg',
#   'Rollag',
#   'Nore og Uvdal',
#   'Innlandet',
#   'Hedmark (-2019)',
#   'Kongsvinger',
#   'Hamar',
#   'Lillehammer',
#   'Gjøvik',
#   'Ringsaker',
#   'Løten',
#   'Stange',
#   'Nord-Odal',
#   'Sør-Odal',
#   'Eidskog',
#   'Grue',
#   'Åsnes',
#   'Våler (Innlandet)',
#   'Elverum',
#   'Trysil',
#   'Åmot',
#   'Stor-Elvdal',
#   'Rendalen',
#   'Engerdal',
#   'Tolga',
#   'Tynset',
#   'Alvdal',
#   'Folldal',
#   'Os',
#   'Dovre',
#   'Lesja',
#   'Skjåk',
#   'Lom',
#   'Vågå',
#   'Nord-Fron',
#   'Sel',
#   'Sør-Fron',
#   'Ringebu',
#   'Øyer',
#   'Gausdal',
#   'Østre Toten',
#   'Vestre Toten',
#   'Gran',
#   'Søndre Land',
#   'Nordre Land',
#   'Sør-Aurdal',
#   'Etnedal',
#   'Nord-Aurdal',
#   'Vestre Slidre',
#   'Øystre Slidre',
#   'Vang',
#   'Hamar (-1991)',
#   'Kongsvinger (-2019)',
#   'Hamar (1992-2019)',
#   'Ringsaker (-2019)',
#   'Vang (-1991)',
#   'Løten (-2019)',
#   'Stange (-2019)',
#   'Nord-Odal (-2019)',
#   'Sør-Odal (-2019)',
#   'Eidskog (-2019)',
#   'Grue (-2019)',
#   'Åsnes (-2019)',
#   'Våler (Hedmark) (-2019)',
#   'Elverum (-2019)',
#   'Trysil (-2019)',
#   'Åmot (-2019)',
#   'Stor-Elvdal (-2019)',
#   'Rendalen (1965-2019)',
#   'Engerdal (1911-2019)',
#   'Tolga-Os (1966-1975)',
#   'Tolga (-2019)',
#   'Tynset (-2019)',
#   'Alvdal (-2019)',
#   'Folldal (1914-2019)',
#   'Os (Hedmark) (1976-2019)',
#   'Unknown municipalities, Hedmark',
#   'Oppland (-2019)',
#   'Lillehammer (-2019)',
#   'Gjøvik (-2019)',
#   'Dovre (-2019)',
#   'Lesja (-2019)',
#   'Skjåk (-2019)',
#   'Lom (-2019)',
#   'Vågå (-2019)',
#   'Nord-Fron (1977-2019)',
#   'Sel (1908-2019)',
#   'Fron (1966-1976)',
#   'Sør-Fron (-2019)',
#   'Ringebu (-2019)',
#   'Øyer (-2019)',
#   'Gausdal (1962-2019)',
#   'Østre Toten (-2019)',
#   'Vestre Toten (-2019)',
#   'Jevnaker (-2019)',
#   'Lunner (-2019)',
#   'Gran (-2019)',
#   'Søndre Land (-2019)',
#   'Nordre Land (-2019)',
#   'Sør-Aurdal (-2019)',
#   'Etnedal (-2019)',
#   'Nord-Aurdal (-2019)',
#   'Vestre Slidre (-2019)',
#   'Øystre Slidre (-2019)',
#   'Vang (-2019)',
#   'Unknown municipalities, Oppland',
#   'Buskerud (-2019)',
#   'Vestfold og Telemark (2020-2023)',
#   'Horten (2020-2023)',
#   'Holmestrand (2020-2023)',
#   'Tønsberg (2020-2023)',
#   'Sandefjord (2020-2023)',
#   'Larvik (2020-2023)',
#   'Porsgrunn (2020-2023)',
#   'Skien (2020-2023)',
#   'Notodden (2020-2023)',
#   'Færder (2020-2023)',
#   'Siljan (2020-2023)',
#   'Bamble (2020-2023)',
#   'Kragerø (2020-2023)',
#   'Drangedal (2020-2023)',
#   'Nome (2020-2023)',
#   'Midt-Telemark (2020-2023)',
#   'Tinn (2020-2023)',
#   'Hjartdal (2020-2023)',
#   'Seljord (2020-2023)',
#   'Kviteseid (2020-2023)',
#   'Nissedal (2020-2023)',
#   'Fyresdal (2020-2023)',
#   'Tokke (2020-2023)',
#   'Vinje (2020-2023)',
#   'Ringerike (1964-1976)',
#   'Drammen (-2019)',
#   'Kongsberg (-2019)',
#   'Ringerike (1977-2019)',
#   'Hole (1977-2019)',
#   'Flå (-2019)',
#   'Nes (Buskerud) (-2019)',
#   'Gol (-2019)',
#   'Hemsedal (-2019)',
#   'Ål (-2019)',
#   'Hol (-2019)',
#   'Sigdal (-2019)',
#   'Krødsherad (-2019)',
#   'Modum (-2019)',
#   'Øvre Eiker (-2019)',
#   'Nedre Eiker (-2019)',
#   'Lier (-2019)',
#   'Røyken (-2019)',
#   'Hurum (-2019)',
#   'Flesberg (-2019)',
#   'Rollag (-2019)',
#   'Nore og Uvdal (1962-2019)',
#   'Vestfold',
#   'Unknown municipalities, Buskerud',
#   'Horten',
#   'Holmestrand',
#   'Tønsberg',
#   'Sandefjord',
#   'Larvik',
#   'Færder',
#   'Telemark',
#   'Porsgrunn',
#   'Skien',
#   'Notodden',
#   'Siljan',
#   'Bamble',
#   'Kragerø',
#   'Drangedal',
#   'Nome',
#   'Midt-Telemark',
#   'Seljord',
#   'Hjartdal',
#   'Tinn',
#   'Kviteseid',
#   'Nissedal',
#   'Fyresdal',
#   'Tokke',
#   'Vinje',
#   'Vestfold (-2019)',
#   'Horten (2002-2019)',
#   'Holmestrand (-2017)',
#   'Horten (-1987)',
#   'Tønsberg (1988-2019)',
#   'Tønsberg (-1987)',
#   'Sandefjord (-2016)',
#   'Larvik (-1987)',
#   'Stavern (1944-1987)',
#   'Larvik (1988-2017)',
#   'Sandefjord (2017-2019)',
#   'Svelvik (1964-2019)',
#   'Larvik (2018-2019)',
#   'Sande (Vestfold) (-2019)',
#   'Hof (-2017)',
#   'Holmestrand (2018-2019)',
#   'Re (2002-2019)',
#   'Våle (-2001)',
#   'Borre (-1987)',
#   'Ramnes (-2001)',
#   'Andebu (-2016)',
#   'Stokke (-2016)',
#   'Sem (-1987)',
#   'Nøtterøy (-2017)',
#   'Tjøme (-2017)',
#   'Sandar (-1967)',
#   'Tjølling (-1987)',
#   'Brunlanes (-1987)',
#   'Hedrum (-1987)',
#   'Lardal (-2017)',
#   'Færder (2018-2019)',
#   'Unknown municipalities, Vestfold',
#   'Telemark (-2019)',
#   'Porsgrunn (-2019)',
#   'Skien (-2019)',
#   'Notodden (1913-2019)',
#   'Siljan (-2019)',
#   'Bamble (-2019)',
#   'Kragerø (1960-2019)',
#   'Drangedal (-2019)',
#   'Nome (1964-2019)',
#   'Bø (Telemark) (-2019)',
#   'Sauherad (-2019)',
#   'Tinn (-2019)',
#   'Hjartdal (-2019)',
#   'Seljord (-2019)',
#   'Kviteseid (-2019)',
#   'Nissedal (-2019)',
#   'Fyresdal (-2019)',
#   'Tokke (1964-2019)',
#   'Vinje (-2019)',
#   'Unknown municipalities, Telemark',
#   'Agder',
#   'Aust-Agder (-2019)',
#   'Risør',
#   'Grimstad',
#   'Arendal',
#   'Kristiansand',
#   'Lindesnes',
#   'Farsund',
#   'Flekkefjord',
#   'Gjerstad',
#   'Vegårshei',
#   'Tvedestrand',
#   'Froland',
#   'Lillesand',
#   'Birkenes',
#   'Åmli',
#   'Iveland',
#   'Evje og Hornnes',
#   'Bygland',
#   'Valle',
#   'Bykle',
#   'Vennesla',
#   'Åseral',
#   'Lyngdal',
#   'Hægebostad',
#   'Kvinesdal',
#   'Sirdal',
#   'Risør (-2019)',
#   'Arendal (-1991)',
#   'Grimstad (-2019)',
#   'Arendal (1992-2019)',
#   'Gjerstad (-2019)',
#   'Vegårshei (-2019)',
#   'Tvedestrand (-2019)',
#   'Moland (1962-1991)',
#   'Froland (-2019)',
#   'Øyestad (-1991)',
#   'Tromøy (-1991)',
#   'Hisøy (-1991)',
#   'Fjære (-1970)',
#   'Landvik (-1970)',
#   'Lillesand (1962-2019)',
#   'Birkenes (-2019)',
#   'Åmli (-2019)',
#   'Mykland (-1966)',
#   'Herefoss (-1966)',
#   'Iveland (-2019)',
#   'Evje og Hornnes (1960-2019)',
#   'Bygland (-2019)',
#   'Valle (-2019)',
#   'Bykle (-2019)',
#   'Unknown municipalities, Aust-Agder',
#   'Vest-Agder (-2019)',
#   'Kristiansand (-2019)',
#   'Mandal (-2019)',
#   'Farsund (-2019)',
#   'Flekkefjord (-2019)',
#   'Vennesla (-2019)',
#   'Songdalen (1964-2019)',
#   'Søgne (-2019)',
#   'Marnardal (1964-2019)',
#   'Åseral (-2019)',
#   'Audnedal (1964-2019)',
#   'Lindesnes (1964-2019)',
#   'Lyngdal (-2019)',
#   'Hægebostad (-2019)',
#   'Kvinesdal (-2019)',
#   'Sirdal (1960-2019)',
#   'Unknown municipalities, Vest-Agder',
#   'Rogaland',
#   'Eigersund',
#   'Sandnes (-2019)',
#   'Stavanger',
#   'Haugesund',
#   'Sandnes',
#   'Sokndal',
#   'Lund',
#   'Bjerkreim',
#   'Hå',
#   'Klepp',
#   'Time',
#   'Gjesdal',
#   'Sola',
#   'Randaberg',
#   'Forsand (-2019)',
#   'Strand',
#   'Hjelmeland',
#   'Suldal',
#   'Sauda',
#   'Finnøy (-2019)',
#   'Rennesøy (-2019)',
#   'Kvitsøy',
#   'Bokn',
#   'Tysvær',
#   'Karmøy',
#   'Utsira',
#   'Vindafjord (1965-2005)',
#   'Ølen (2002-2005)',
#   'Vindafjord',
#   'Unknown municipalities, Rogaland',
#   'Vestland',
#   'Hordaland (-2019)',
#   'Bergen',
#   'Kinn',
#   'Etne',
#   'Sveio',
#   'Bømlo',
#   'Stord',
#   'Fitjar',
#   'Tysnes',
#   'Kvinnherad',
#   'Ullensvang',
#   'Eidfjord',
#   'Ulvik',
#   'Voss',
#   'Kvam',
#   'Samnanger',
#   'Bjørnafjorden',
#   'Austevoll',
#   'Øygarden',
#   'Askøy',
#   'Vaksdal',
#   'Modalen',
#   'Osterøy',
#   'Alver',
#   'Austrheim',
#   'Fedje',
#   'Masfjorden',
#   'Gulen',
#   'Solund',
#   'Hyllestad',
#   'Høyanger',
#   'Vik',
#   'Sogndal',
#   'Aurland',
#   'Lærdal',
#   'Årdal',
#   'Luster',
#   'Askvoll',
#   'Fjaler',
#   'Sunnfjord',
#   'Bremanger',
#   'Stad',
#   'Gloppen',
#   'Stryn',
#   'Bergen (1972-2019)',
#   'Etne (-2019)',
#   'Ølen (1916-2001)',
#   'Sveio (-2019)',
#   'Bømlo (1916-2019)',
#   'Stord (-2019)',
#   'Fitjar (-2019)',
#   'Tysnes (-2019)',
#   'Kvinnherad (-2019)',
#   'Jondal (-2019)',
#   'Odda (1913-2019)',
#   'Ullensvang (-1976)',
#   'Ullensvang (1977-2019)',
#   'Eidfjord (-2019)',
#   'Ulvik (-2019)',
#   'Granvin (-2019)',
#   'Voss (-2019)',
#   'Kvam (-2019)',
#   'Fusa (-2019)',
#   'Samnanger (1907-2019)',
#   'Os (Hordaland) (-2019)',
#   'Austevoll (-2019)',
#   'Sund (-2019)',
#   'Fjell (-2019)',
#   'Askøy (-2019)',
#   'Laksevåg (1918-1971)',
#   'Fana (-1971)',
#   'Arna (1964-1971)',
#   'Vaksdal (1964-2019)',
#   'Modalen (1910-2019)',
#   'Osterøy (1964-2019)',
#   'Åsane (-1971)',
#   'Meland (1924-2019)',
#   'Øygarden (1964-2019)',
#   'Radøy (1964-2019)',
#   'Lindås (-2019)',
#   'Austrheim (1910-2019)',
#   'Fedje (1948-2019)',
#   'Masfjorden (-2019)',
#   'Unknown municipalities, Hordaland',
#   'Bergen (-1971)',
#   'Bergen (-1971)',
#   'Sogn og Fjordane (-2019)',
#   'Flora (1964-2019)',
#   'Gulen (-2019)',
#   'Solund (-2019)',
#   'Hyllestad (-2019)',
#   'Høyanger (1964-2019)',
#   'Vik (-2019)',
#   'Balestrand (-2019)',
#   'Leikanger (-2019)',
#   'Sogndal (-2019)',
#   'Aurland (-2019)',
#   'Lærdal (-2019)',
#   'Årdal (-2019)',
#   'Luster (-2019)',
#   'Askvoll (-2019)',
#   'Fjaler (-2019)',
#   'Gaular (-2019)',
#   'Jølster (-2019)',
#   'Førde (-2019)',
#   'Naustdal (-2019)',
#   'Bremanger (-2019)',
#   'Vågsøy (1964-2019)',
#   'Selje (-2019)',
#   'Eid (-2019)',
#   'Hornindal (-2019)',
#   'Gloppen (-2019)',
#   'Stryn (-1976)',
#   'Stryn (1977-2019)',
#   'Unknown municipalities, Sogn og Fjordane',
#   'Møre og Romsdal',
#   'Ålesund (-1976)',
#   'Molde (-2019)',
#   'Kristiansund  (-2007)',
#   'Ålesund (1977-2019)',
#   'Kristiansund',
#   'Molde',
#   'Ålesund (2020-2023)',
#   'Ålesund',
#   'Vanylven',
#   'Sande',
#   'Herøy (Møre og Romsdal)',
#   'Ulstein',
#   'Hareid',
#   'Volda (-2019)',
#   'Ørsta',
#   'Ørskog (1977-2019)',
#   'Norddal (-2019)',
#   'Stranda',
#   'Stordal (-2019)',
#   'Ørskog (-1976)',
#   'Sykkylven',
#   'Skodje (-2019)',
#   'Sula',
#   'Giske',
#   'Haram (-2019)',
#   'Vestnes',
#   'Rauma',
#   'Nesset (-2019)',
#   'Midsund (1965-2019)',
#   'Sandøy (-2019)',
#   'Aukra',
#   'Fræna (-2019)',
#   'Eide (-2019)',
#   'Averøy',
#   'Frei (-2007)',
#   'Gjemnes',
#   'Tingvoll',
#   'Sunndal',
#   'Surnadal',
#   'Rindal (-2018)',
#   'Aure (-2005)',
#   'Halsa (-2019)',
#   'Tustna (-2005)',
#   'Smøla',
#   'Aure',
#   'Volda',
#   'Fjord',
#   'Hustadvika',
#   'Haram',
#   'Unknown municipalities, Møre og Romsdal',
#   'Trøndelag - Trööndelage',
#   'Sør-Trøndelag (-2017)',
#   'Trondheim - Tråante',
#   'Steinkjer (2018-2019)',
#   'Namsos (2018-2019)',
#   'Steinkjer',
#   'Namsos - Nåavmesjenjaelmie',
#   'Hemne (2018-2019)',
#   'Snillfjord (2018-2019)',
#   'Hitra (2018-2019)',
#   'Frøya',
#   'Ørland (2018-2019)',
#   'Agdenes (2018-2019)',
#   'Bjugn (2018-2019)',
#   'Åfjord (2018-2019)',
#   'Roan (2018-2019)',
#   'Osen',
#   'Oppdal',
#   'Rennebu',
#   'Meldal (2018-2019)',
#   'Orkdal (2018-2019)',
#   'Røros - Rosse',
#   'Holtålen',
#   'Midtre Gauldal',
#   'Melhus',
#   'Skaun',
#   'Klæbu (2018-2019)',
#   'Malvik',
#   'Selbu',
#   'Tydal',
#   'Meråker',
#   'Stjørdal',
#   'Frosta',
#   'Levanger - Levangke',
#   'Verdal',
#   'Verran (2018-2019)',
#   'Namdalseid (2018-2019)',
#   'Snåase - Snåsa',
#   'Lierne',
#   'Raarvihke - Røyrvik',
#   'Namsskogan',
#   'Grong',
#   'Høylandet',
#   'Overhalla',
#   'Fosnes (2018-2019)',
#   'Flatanger',
#   'Vikna (2018-2019)',
#   'Nærøy (2018-2019)',
#   'Leka',
#   'Inderøy',
#   'Indre Fosen',
#   'Heim',
#   'Hitra',
#   'Ørland',
#   'Åfjord',
#   'Orkland',
#   'Nærøysund',
#   'Rindal',
#   'Trondheim (-2017)',
#   'Hemne (-2017)',
#   'Snillfjord (1924-2017)',
#   'Hitra (-2017)',
#   'Frøya (1964-2017)',
#   'Ørland (-2017)',
#   'Agdenes (-2017)',
#   'Rissa (-2017)',
#   'Bjugn (-2017)',
#   'Åfjord (-2017)',
#   'Roan (-2017)',
#   'Osen (-2017)',
#   'Oppdal (-2017)',
#   'Rennebu (-2017)',
#   'Meldal (-2017)',
#   'Orkdal (-2017)',
#   'Røros (-2017)',
#   'Holtålen (1972-2017)',
#   'Haltdalen (-1971)',
#   'Midtre Gauldal (1964-2017)',
#   'Melhus (-2017)',
#   'Skaun (-2017)',
#   'Klæbu (-2017)',
#   'Malvik (-2017)',
#   'Selbu (-2017)',
#   'Tydal (-2017)',
#   'Unknown municipalities, Sør-Trøndelag',
#   'Nord-Trøndelag (-2017)',
#   'Steinkjer (-2017)',
#   'Namsos (-2017)',
#   'Meråker (-2017)',
#   'Stjørdal (-2017)',
#   'Frosta (-2017)',
#   'Leksvik (-2017)',
#   'Levanger (1962-2017)',
#   'Verdal (-2017)',
#   'Mosvik  (-2011)',
#   'Verran (-2017)',
#   'Namdalseid (-2017)',
#   'Inderøy (-2011)',
#   'Snåase - Snåsa (-2017)',
#   'Lierne (1964-2017)',
#   'Raarvihke - Røyrvik (1923-2017)',
#   'Namsskogan (1923-2017)',
#   'Grong (-2017)',
#   'Høylandet (-2017)',
#   'Overhalla (-2017)',
#   'Fosnes (-2017)',
#   'Flatanger (-2017)',
#   'Vikna (-2017)',
#   'Nærøy (-2017)',
#   'Leka (-2017)',
#   'Inderøy (2012-2017)',
#   'Unknown municipalities, Nord-Trøndelag',
#   'Nordland - Nordlánnda',
#   'Bodø',
#   'Narvik (-2019)',
#   'Narvik',
#   'Bindal',
#   'Sømna',
#   'Brønnøy',
#   'Brønnøy (-1976)',
#   'Vega',
#   'Vevelstad',
#   'Herøy (Nordland)',
#   'Alstahaug',
#   'Leirfjord',
#   'Vefsn',
#   'Grane',
#   'Aarborte - Hattfjelldal',
#   'Dønna',
#   'Nesna',
#   'Hemnes',
#   'Rana - Raane',
#   'Lurøy',
#   'Træna',
#   'Rødøy',
#   'Meløy',
#   'Gildeskål',
#   'Beiarn',
#   'Saltdal',
#   'Fauske - Fuosko',
#   'Skjerstad (-2004)',
#   'Bodin (-1967)',
#   'Sørfold - Fuolldá',
#   'Steigen',
#   'Hamarøy - Hábmer (-2019)',
#   'Divtasvuodna - Tysfjord (-2019)',
#   'Lødingen',
#   'Tjeldsund (1909-2019)',
#   'Evenes - Evenássi',
#   'Ballangen (1925-2019)',
#   'Ankenes (-1973)',
#   'Røst',
#   'Værøy',
#   'Moskenes (1916-1975)',
#   'Flakstad',
#   'Vestvågøy',
#   'Vågan',
#   'Hadsel',
#   'Bø (Nordland)',
#   'Øksnes',
#   'Sortland - Suortá',
#   'Andøy',
#   'Moskenes',
#   'Hábmer - Hamarøy',
#   'Troms - Romsa - Tromssa',
#   'Finnmark - Finnmárku - Finmarkku',
#   'Unknown municipalities, Nordland',
#   'Tromsø',
#   'Harstad - Hárstták',
#   'Kvæfjord',
#   'Dielddanuorri - Tjeldsund',
#   'Ibestad',
#   'Gratangen - Rivtták',
#   'Loabák - Lavangen',
#   'Bardu',
#   'Salangen',
#   'Målselv',
#   'Sørreisa',
#   'Dyrøy',
#   'Senja',
#   'Balsfjord',
#   'Karlsøy',
#   'Lyngen',
#   'Storfjord - Omasvuotna - Omasvuono',
#   'Gáivuotna - Kåfjord - Kaivuono',
#   'Skjervøy',
#   'Nordreisa - Ráisa - Raisi',
#   'Kvænangen',
#   'Alta',
#   'Hammerfest - Hámmerfeasta',
#   'Sør-Varanger',
#   'Vadsø',
#   'Kárásjohka - Karasjok',
#   'Guovdageaidnu - Kautokeino',
#   'Loppa',
#   'Hasvik',
#   'Måsøy',
#   'Nordkapp',
#   'Porsanger - Porsángu - Porsanki',
#   'Lebesby',
#   'Gamvik',
#   'Deatnu - Tana',
#   'Berlevåg',
#   'Båtsfjord',
#   'Vardø',
#   'Unjárga - Nesseby',
#   'Troms og Finnmark - Romsa ja Finnmárku (2020-2023)',
#   'Troms - Romsa (-2019)',
#   'Tromsø (2020-2023)',
#   'Harstad - Hárstták (2020-2023)',
#   'Alta (2020-2023)',
#   'Vardø (2020-2023)',
#   'Vadsø (2020-2023)',
#   'Hammerfest - Hámmerfeasta (2020-2023)',
#   'Kvæfjord (2020-2023)',
#   'Dielddanuorri - Tjeldsund (2020-2023)',
#   'Ibestad (2020-2023)',
#   'Gratangen (2020-2023)',
#   'Loabák - Lavangen (2020-2023)',
#   'Bardu (2020-2023)',
#   'Salangen (2020-2023)',
#   'Målselv (2020-2023)',
#   'Sørreisa (2020-2023)',
#   'Dyrøy (2020-2023)',
#   'Senja (2020-2023)',
#   'Balsfjord (2020-2023)',
#   'Karlsøy (2020-2023)',
#   'Lyngen (2020-2023)',
#   'Storfjord - Omasvuotna - Omasvuono (2020-2023)',
#   'Gáivuotna - Kåfjord - Kaivuono (2020-2023)',
#   'Skjervøy (2020-2023)',
#   'Nordreisa - Ráisa - Raisi (2020-2023)',
#   'Kvænangen (2020-2023)',
#   'Guovdageaidnu - Kautokeino (2020-2023)',
#   'Loppa (2020-2023)',
#   'Hasvik (2020-2023)',
#   'Måsøy (2020-2023)',
#   'Nordkapp (2020-2023)',
#   'Porsanger - Porsángu - Porsanki (2020-2023)',
#   'Kárásjohka - Karasjok (2020-2023)',
#   'Lebesby (2020-2023)',
#   'Gamvik (2020-2023)',
#   'Berlevåg (2020-2023)',
#   'Deatnu - Tana (2020-2023)',
#   'Unjárga - Nesseby (2020-2023)',
#   'Båtsfjord (2020-2023)',
#   'Sør-Varanger (2020-2023)',
#   'Harstad (-2012)',
#   'Tromsø (-2019)',
#   'Harstad - Hárstták (2013-2019)',
#   'Kvæfjord (-2019)',
#   'Skånland (1926-2019)',
#   'Bjarkøy (-2012)',
#   'Ibestad (-2019)',
#   'Gratangen (1926-2019)',
#   'Loabák - Lavangen (1907-2019)',
#   'Salangen (-1976)',
#   'Bardu (-2019)',
#   'Salangen (1977-2019)',
#   'Målselv (-2019)',
#   'Sørreisa (-2019)',
#   'Dyrøy (-2019)',
#   'Tranøy (-2019)',
#   'Torsken (-2019)',
#   'Berg (-2019)',
#   'Lenvik (-2019)',
#   'Balsfjord (-2019)',
#   'Karlsøy (-2019)',
#   'Lyngen (-2019)',
#   'Storfjord - Omasvuotna - Omasvuono (1931-2019)',
#   'Gáivuotna - Kåfjord - Kaivuono (1931-2019)',
#   'Skjervøy (-2019)',
#   'Nordreisa - Ráisa - Raisi (-2019)',
#   'Kvænangen (-2019)',
#   'Unknown municipalities, Troms',
#   'Finnmark - Finnmárku (-2019)',
#   'Hammerfest (-1991)',
#   'Vardø (-2019)',
#   'Vadsø (-2019)',
#   'Hammerfest (1992-2019)',
#   'Guovdageaidnu - Kautokeino (-2019)',
#   'Alta (-2019)',
#   'Loppa (-2019)',
#   'Hasvik (-2019)',
#   'Sørøysund (-1991)',
#   'Kvalsund (-2019)',
#   'Måsøy (-2019)',
#   'Nordkapp (-2019)',
#   'Porsanger - Porsángu - Porsanki (1964-2019)',
#   'Kárásjohka - Karasjok (-2019)',
#   'Lebesby (-2019)',
#   'Gamvik (1914-2019)',
#   'Berlevåg (1914-2019)',
#   'Deatnu - Tana (-2019)',
#   'Unjárga - Nesseby (-2019)',
#   'Båtsfjord (1955-2019)',
#   'Sør-Varanger (-2019)',
#   'Unknown municipalities, Finnmark',
#   'Svalbard',
#   'Colesbukta planning area',
#   'Pyramiden planning area',
#   'Van Mijenfjorden',
#   'Nordenskiöld Land nationalpark',
#   'Isfjorden',
#   'Sassen-Bünsow Land nationalpark',
#   'Nordre Isfjorden nationalpark',
#   'Kongsfjorden',
#   'Forlandet nationalpark',
#   'Wijdefjorden',
#   'Longyearbyen planning area',
#   'Ny-Ålesund planning area',
#   'Barentsburg planning area',
#   'Sør-Spitsbergen nationalpark',
#   'Sveagruva planning area',
#   'Indre Wijdefjorden nationalpark',
#   'Nordvest-Spitsbergen nationalpark',
#   'Nordaust-Svalbard naturereserve',
#   'Søraust-Svalbard naturereserve',
#   'Bjørnøya naturereserve',
#   'Hopen naturereserve',
#   'Unknown munipalities in Svalbard',
#   'Jan Mayen',
#   'Jan Mayen',
#   'Unknown  in Jan Mayen',
#   'The Continental Shelf',
#   'Continental shelf',
#   'The continental shelf south of 62 degrees north latitude',
#   'The continental shelf north of 62 degrees north latitude',
#   'The continental shelf, unspecified',
#   'Abroad',
#   'Ocean areas',
#   'Not resident in Norway',
#   'County not stated',
#   'Unknown municipality'],
#  'densely/sparsely populated areas': ['Densely populated area',
#   'Sparsley populated area',
#   'Unknown'],
#  'sex': ['Females', 'Males'],
#  'contents': ['Population'],
#  'year': ['1990',
#   '1991',
#   '1992',
#   '1993',
#   '1994',
#   '1995',
#   '1996',
#   '1997',
#   '1998',
#   '1999',
#   '2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2011',
#   '2012',
#   '2013',
#   '2014',
#   '2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2022',
#   '2023',
#   '2024']}

# %% [markdown]
# Now that we have these, we can choose what we are interested in and create a json query. Let's say we are interested in the number of inhabitants per square kilometer in Örebro county the latest five years.

# %%
ssb.set_query(region=["Oslo"], 
              observations=["densely/sparsely populated areas"], 
              year=["2014", "2015", "2016", "2017", "2018"])

# %% [markdown]
# Now we can check how the query looks:

# %%
ssb.get_query()
# Out:
# {'query': [{'code': 'Region',
#    'selection': {'filter': 'item', 'values': ['03']}},
#   {'code': 'Tid',
#    'selection': {'filter': 'item',
#     'values': ['2014', '2015', '2016', '2017', '2018']}}],
#  'response': {'format': 'json'}}

# %% [markdown]
# The query is automatically formatted in the right way to fetch the data from the API. We fetch the data:

# %%
ssb.get_data()
# Out:
# {'columns': [{'code': 'Region', 'text': 'region', 'type': 'd'},
#   {'code': 'Tid', 'text': 'year', 'type': 't'},
#   {'code': 'Folkemengde', 'text': 'Population', 'type': 'c'}],
#  'comments': [],
#  'data': [{'key': ['03', '2014'], 'values': ['634463']},
#   {'key': ['03', '2015'], 'values': ['647676']},
#   {'key': ['03', '2016'], 'values': ['658390']},
#   {'key': ['03', '2017'], 'values': ['666759']},
#   {'key': ['03', '2018'], 'values': ['673469']}],
#  'metadata': [{'infofile': 'None',
#    'updated': '2024-10-01T06:00:00Z',
#    'label': '05212: Population, by region, year and contents',
#    'source': 'Statistics Norway'}]}

# %% [markdown]
# This is the same data that one can fetch from the Statistical Database on the website. Via a function in pyscbwrapper we can get the URL to the page with the data:

# %%
ssb.get_url()
# Out:
# 'https://data.ssb.no/api/v0/en/table/START__be__be05__beftett/FolkTettSpredt'

# %% [markdown]
# The data can of course be fetched without pyscbwrapper, by navigating to the URL above. There we select "Population density per sq. km", choose region County and select Örebro county, and select the last five years. On the next page we can click "API for this table" and get the query and a URL to post it to via e.g. the package requests, but he have to change "format": "px" to "format": "json".

# %%
import requests
import json

session = requests.Session()

query = {
  "query": [
    {
      "code": "Region",
      "selection": {
        "filter": "vs:RegionLän99EjAggr",
        "values": [
          "18"
        ]
      }
    },
    {
      "code": "ContentsCode",
      "selection": {
        "filter": "item",
        "values": [
          "BE0101U1"
        ]
      }
    },
    {
      "code": "Tid",
      "selection": {
        "filter": "item",
        "values": [
          "2014",
          "2015",
          "2016",
          "2017",
          "2018"
        ]
      }
    }
  ],
  "response": {
    "format": "json"
  }
}

url = "https://api.scb.se/OV0104/v1/doris/en/ssd/START/BE/BE0101/BE0101C/BefArealTathetKon"

response = session.post(url, json=query)
response_json = json.loads(response.content.decode('utf-8-sig'))

response_json
# Out:
# {'columns': [{'code': 'Region', 'text': 'region', 'type': 'd'},
#   {'code': 'Tid', 'text': 'year', 'type': 't'},
#   {'code': 'BE0101U1', 'text': 'Population density per sq. km', 'type': 'c'}],
#  'comments': [],
#  'data': [{'key': ['18', '2014'], 'values': ['33.9']},
#   {'key': ['18', '2015'], 'values': ['34.2']},
#   {'key': ['18', '2016'], 'values': ['34.7']},
#   {'key': ['18', '2017'], 'values': ['35.1']},
#   {'key': ['18', '2018'], 'values': ['35.5']}]}

# %% [markdown]
# As you can see, we get the exact same data.

# %% [markdown]
# # More advanced calls

# %% [markdown]
# Now that we have seen what the data looks like we can fetch more of it to make interesting graphs. Since we already are on the correct place in the API structure we only have to construct a new query. Let's say we want data from every available year for each county. First we can pick out a list over all regions, filter out the counties through regular expressions, and after that use the list in the json query:

# %%
import re

regions = ssb.get_variables()['region']
r = re.compile(r'.* county')
county = list(filter(r.match, regions))

ssb.set_query(region=county,
              observations=["Population density per sq. km"])

# %%
scb.get_query()
# Out:
# {'query': [{'code': 'Region',
#    'selection': {'filter': 'item',
#     'values': ['01',
#      '03',
#      '04',
#      '05',
#      '06',
#      '07',
#      '08',
#      '09',
#      '10',
#      '12',
#      '13',
#      '14',
#      '17',
#      '18',
#      '19',
#      '20',
#      '21',
#      '22',
#      '23',
#      '24',
#      '25']}},
#   {'code': 'ContentsCode',
#    'selection': {'filter': 'item', 'values': ['BE0101U1']}}],
#  'response': {'format': 'json'}}

# %% [markdown]
# This is the exact query we need. We fetch the data and place it in a variable so we can use it later:

# %%
ssb_data = ssb.get_data()

# %% [markdown]
# As is good practice we look at the data before we do anything else:

# %%
ssb_data
# Out:
# {'columns': [{'code': 'Tid', 'text': 'year', 'type': 't'},
#   {'code': 'Folkemengde', 'text': 'Population', 'type': 'c'}],
#  'comments': [],
#  'data': [{'key': ['1990'], 'values': ['4233116']},
#   {'key': ['1991'], 'values': ['4249830']},
#   {'key': ['1992'], 'values': ['4273634']},
#   {'key': ['1993'], 'values': ['4299167']},
#   {'key': ['1994'], 'values': ['4324815']},
#   {'key': ['1995'], 'values': ['4348410']},
#   {'key': ['1996'], 'values': ['4369957']},
#   {'key': ['1997'], 'values': ['4392714']},
#   {'key': ['1998'], 'values': ['4417599']},
#   {'key': ['1999'], 'values': ['4445329']},
#   {'key': ['2000'], 'values': ['4478497']},
#   {'key': ['2001'], 'values': ['4503436']},
#   {'key': ['2002'], 'values': ['4524066']},
#   {'key': ['2003'], 'values': ['4552252']},
#   {'key': ['2004'], 'values': ['4577457']},
#   {'key': ['2005'], 'values': ['4606363']},
#   {'key': ['2006'], 'values': ['4640219']},
#   {'key': ['2007'], 'values': ['4681134']},
#   {'key': ['2008'], 'values': ['4737171']},
#   {'key': ['2009'], 'values': ['4799252']},
#   {'key': ['2011'], 'values': ['4920305']},
#   {'key': ['2012'], 'values': ['4985870']},
#   {'key': ['2013'], 'values': ['5051275']},
#   {'key': ['2014'], 'values': ['5109056']},
#   {'key': ['2015'], 'values': ['5165802']},
#   {'key': ['2016'], 'values': ['5213985']},
#   {'key': ['2017'], 'values': ['5258317']},
#   {'key': ['2018'], 'values': ['5295619']},
#   {'key': ['2019'], 'values': ['5328212']},
#   {'key': ['2020'], 'values': ['5367580']},
#   {'key': ['2021'], 'values': ['5391369']},
#   {'key': ['2022'], 'values': ['5425270']},
#   {'key': ['2023'], 'values': ['5488984']},
#   {'key': ['2024'], 'values': ['5550203']}],
#  'metadata': [{'infofile': 'None',
#    'updated': '2024-10-01T06:00:00Z',
#    'label': '05212: Population, by year and contents',
#    'source': 'Statistics Norway'}]}

# %% [markdown]
# The actual data we look for is here:

# %%
scb_fetch = ssb_data['data']

# %% [markdown]
# Once again we check that we have gotten the correct data:

# %%
scb_fetch
# Out:
# [{'key': ['1990'], 'values': ['4233116']},
#  {'key': ['1991'], 'values': ['4249830']},
#  {'key': ['1992'], 'values': ['4273634']},
#  {'key': ['1993'], 'values': ['4299167']},
#  {'key': ['1994'], 'values': ['4324815']},
#  {'key': ['1995'], 'values': ['4348410']},
#  {'key': ['1996'], 'values': ['4369957']},
#  {'key': ['1997'], 'values': ['4392714']},
#  {'key': ['1998'], 'values': ['4417599']},
#  {'key': ['1999'], 'values': ['4445329']},
#  {'key': ['2000'], 'values': ['4478497']},
#  {'key': ['2001'], 'values': ['4503436']},
#  {'key': ['2002'], 'values': ['4524066']},
#  {'key': ['2003'], 'values': ['4552252']},
#  {'key': ['2004'], 'values': ['4577457']},
#  {'key': ['2005'], 'values': ['4606363']},
#  {'key': ['2006'], 'values': ['4640219']},
#  {'key': ['2007'], 'values': ['4681134']},
#  {'key': ['2008'], 'values': ['4737171']},
#  {'key': ['2009'], 'values': ['4799252']},
#  {'key': ['2011'], 'values': ['4920305']},
#  {'key': ['2012'], 'values': ['4985870']},
#  {'key': ['2013'], 'values': ['5051275']},
#  {'key': ['2014'], 'values': ['5109056']},
#  {'key': ['2015'], 'values': ['5165802']},
#  {'key': ['2016'], 'values': ['5213985']},
#  {'key': ['2017'], 'values': ['5258317']},
#  {'key': ['2018'], 'values': ['5295619']},
#  {'key': ['2019'], 'values': ['5328212']},
#  {'key': ['2020'], 'values': ['5367580']},
#  {'key': ['2021'], 'values': ['5391369']},
#  {'key': ['2022'], 'values': ['5425270']},
#  {'key': ['2023'], 'values': ['5488984']},
#  {'key': ['2024'], 'values': ['5550203']}]

# %% [markdown]
# Now we need to understand the structure of the data. We have gotten a list of dictionaries where the first variable 'key' contains the domain (in this case county and year), and the variable 'values' contains the value of the observation variable (in this case inhabitants per square kilometer). To change this into time series that can be used for visualisation we need a few syntactic tricks that are described below.

# %% [markdown]
# # Data processing

# %% [markdown]
# What we look for is one time series per county. Therefore we need to restructure the data we have gotten before we can do anything. This is outside the functionality of pyscbwrapper, but we can easily solve it. A good structure would be a dictionary with county as key and another dictionary as value, where the inner dictionary has year as key and variable value as value. To achieve this we take the list of counties that we created earlier and connect it to the county codes, which we can take from their place in get_query(), in this case 0. By comparing these codes, which are now connected to the county names, to the codes in the data, we can connect the county names to the data.
#
# This way we create the structure we want, and we take the opportunity to cast the the values as numeric.

# %%
codes = ssb.get_query()['query'][0]['selection']['values']

countydic = {}
for i in range(len(codes)):
  countydic[codes[i]] = county[i]


countydata = {}

for code in countydic:
  countydata[countydic[code]] = {}
  for i in range(len(scb_fetch)):
    if ssb_fetch[i]['key'][0] == code:
      countydata[countydic[code]][scb_fetch[i]['key'][1]] = \
      float(ssb_fetch[i]['values'][0])

# %% [markdown]
# This got a bit hacky, so let's see if we got the structure we wanted:

# %%
countydata
# Out:
# {}

# %% [markdown]
# This looks about right. Now we can loop over the keys and plot the values using key on the x axis and value on the y axis.

# %% [markdown]
# # Data visualisation

# %% [markdown]
# We need numpy, pandas, and matplotlib for this. We install and import.

# %%
# !pip install -q matplotlib
# !pip install -q pandas
# !pip install -q numpy

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Now we can make a neat graph.

# %%
df = pd.DataFrame(countydata)
df = df.reset_index()
df = df.rename(columns={"index":"Year"})
ax = df.plot(x=df.index, xticks=np.arange(len(df.index)), colormap='hsv')
ax.set_xticklabels(df["Year"], rotation=45)
plt.title("Population density per county")
plt.xlabel("Year")
plt.ylabel("Inhabitants per square kilometer")
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 4
#       2 df = df.reset_index()
#       3 df = df.rename(columns={"index":"Year"})
# ----> 4 ax = df.plot(x=df.index, xticks=np.arange(len(df.index)), colormap='hsv')
#       5 ax.set_xticklabels(df["Year"], rotation=45)
#       6 plt.title("Population density per county")
#
# File C:\ProgramData\miniconda3\Lib\site-packages\pandas\plotting\_core.py:996, in PlotAccessor.__call__(self, *args, **kwargs)
#     994         x = data_cols[x]
#     995     elif not isinstance(data[x], ABCSeries):
# --> 996         raise ValueError("x must be a label or position")
#     997     data = data.set_index(x)
#     998 if y is not None:
#     999     # check if we have y as int or list of ints
#
# ValueError: x must be a label or position

# %% [markdown]
# Now we have what we wanted, and we never left the Python environment!
